# %% [markdown]
# ## Importing Necessary Libraries

# %%
# data analysis and wrangling
import pandas as pd
import numpy as np
import random as rnd
import nltk
import nltk as nk
from nltk import wordnet
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
from nltk.tokenize import PunktSentenceTokenizer,word_tokenize, sent_tokenize
from nltk import FreqDist
from nltk.corpus import stopwords
import re

# %% [markdown]
# ### Installing NLTK

# %%
 ! pip install -U nltk

 nltk.download('punkt')
 nltk.download("popular")
# Out:
# Requirement already up-to-date: nltk in /usr/local/lib/python3.6/dist-packages (3.4.5)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.6/dist-packages (from nltk) (1.12.0)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gazetteers.zip.
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/genesis.zip.
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gutenberg.zip.
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/inaugural.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/movie_reviews.zip.
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/names.zip.
# [nltk_data]    | Downloading package shakespeare to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/shakespeare.zip.
# [nltk_data]    | Downloading package stopwords to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/stopwords.zip.
# [nltk_data]    | Downloading package treebank to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/treebank.zip.
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/twitter_samples.zip.
# [nltk_data]    | Downloading package omw to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/omw.zip.
# [nltk_data]    | Downloading package wordnet to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet.zip.
# [nltk_data]    | Downloading package wordnet_ic to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet_ic.zip.
# [nltk_data]    | Downloading package words to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/words.zip.
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data]    | Downloading package punkt to /root/nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    |
# [nltk_data]  Done downloading collection popular
# True

# %% [markdown]
# ### Loading the saved data as plain text

# %% [markdown]
# ### Choosing file from local disk

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-bb6006ef-4d2b-4e0c-84c1-8b535f085d94" name="files[]" multiple disabled />
#      <output id="result-bb6006ef-4d2b-4e0c-84c1-8b535f085d94">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving data.csv to data.csv

# %% [markdown]
# ### Downloading the Dataset

# %% [markdown]
# #### Dataset for Detailed Patent Litigation

# %%
#! git clone https://www.kaggle.com/uspto/patent-litigations#cases.csv

# %% [markdown]
# #### Dataset for citation

# %%
#! git clone http://aminer.org/lab-datasets/citation/DBLP_citation_2014_May.zip

# %% [markdown]
# #### Dataset for Twitter

# %%
#! git clone https://www.kaggle.com/c/twitter-sentiment-analysis2/data

# %% [markdown]
# ### Reading csv files

# %%
def readCSVFile():
    # Reading training and test files to list data structures
    data = pd.read_csv("data.csv", error_bad_lines=False, sep = "\t", index_col=False, encoding='latin-1',low_memory=False)
    df = pd.DataFrame(data)
    return df
sentiments = readCSVFile()
x = sentiments["SentimentText"].str.replace('http\S+|www.\S+', '', case=False)
text = x.str.replace('[^a-zA-Z0-9-_*.]', ' ')
data = (', '.join(text))
data
# Out:
# '                     is so sad for my APL friend.............,                    I missed the New Moon trailer...,               omg its already 7 30  O,           .. Omgaga. Im sooo  im gunna CRy. I ve been at this dentist since 11.. I was suposed 2 just get a crown put on  30mins ...,          i think mi bf is cheating on me          T_T,          or i just worry too much         ,        Juuuuuuuuuuuuuuuuussssst Chillin  ,        Sunny Again        Work Tomorrow   -        TV Tonight,       handed in my uniform today . i miss you already,       hmmmm.... i wonder how she my number  - ,       I must think about positive..,       thanks to all the haters up in my face all day  112-102,       this weekend has sucked so far,      jb isnt showing in australia any more ,      ok thats it you win.,      lt -------- This is the way i feel right now...,     awhhe man.... I m completely useless rt now. Funny  all I can do is twitter. ,     Feeling strangely fine. Now I m gonna go listen to some Semisonic to celebrate,     HUGE roll of thunder just now...SO scary    ,     I just cut my beard off. It s only been growing for well over a year. I m gonna start it over.  shaunamanu is happy in the meantime.,     Very sad about Iran.,     wompppp wompp,     You re the only one who can see this cause no one else is following me this is for you because you re pretty awesome,     lt ---Sad level is 3. I was writing a massive blog tweet on Myspace and my comp shut down. Now it s all lost *lays in fetal position*,    ...  Headed to Hospitol   Had to pull out of the Golf Tourny in 3rd place            I Think I Re-Ripped something     Yeah THAT   ,    BoRinG      whats wrong with him       Please tell me........    - ,    can t be bothered. i wish i could spend the rest of my life just sat here and going to gigs. seriously.,    Feeeling like shit right now. I really want to sleep  but nooo I have 3 hours of dancing and an art assignment to finish. ,    goodbye exams  HELLO ALCOHOL TONIGHT ,    I didn t realize it was THAT deep. Geez give a girl a warning atleast ,    I hate it when any athlete appears to tear an ACL on live television.,    i miss you guys too     i think i m wearing skinny jeans a cute sweater and heels   not really sure   what are you doing today,   -- Meet your Meat ,    My horsie is moving on Saturday morning.,    No Sat off...Need to work 6 days a week ,    Really Dont Like Doing my Room Its So Boring  Sick Of Doing My Wardrobe Out Cant Waiit Till I Have My Walk In One  Yay,    SOX      Floyd was great  but relievers need a scolding ,    times by like a million,    uploading pictures on friendster ,    what type of a spaz downloads a virus  my brother that s who    MSN is now fucked forever       ,    amp  amp Fightiin Wiit The Babes...,             - so i wrote something last week. and i got a call from someone in the new york office... ,   *enough said*,   ... Do I need to even say it   Do I   Well  here I go anyways   CHRIS CORNELL IN CHICAGO   ... TONIGHT     ,   ... health class  what a joke  ,    ginaaa  lt 3 GO TO THE SHOW TONIGHT,    Spiral_galaxy  YMPtweet  it really makes me sad when i look at Muslims reality now,  - All Time Low shall be my motivation for the rest of the week.,   and the entertainment is over  someone complained properly..    rupturerapture experimental you say  he should experiment with a melody,   another year of Lakers .. That s neither magic nor fun ...,   baddest day eveer. ,   bathroom is clean..... now on to more enjoyable tasks......,   boom boom pow,   but i m proud.,   congrats to helio though,   David must be hospitalized for five days end of July  palatine tonsils . I will probably never see Katie in concert. ,   friends are leaving me  cause of this stupid love  ,   go give ur mom a hug right now. ,   Going To See Harry Sunday Happiness ,   Hand quilting it is then...,   hate u ...  leysh t9ar5 ...          ..,  -  I always get what I want,   I bend backwards  ,   i get off work sooo ...

# %% [markdown]
# ## Data preperation - Feature Extraction

# %%
lemmatizer = WordNetLemmatizer() # For word lemmatization
stemmer = PorterStemmer() # For word Stemming
REPLACE_BY_SPACE = re.compile('[/(){}\[\]\|@,;]') 
BAD_SYMBOLS = re.compile('[^0-9a-z #+_]')
REMOVING_NUMBERS = re.compile("(^|\W)\d+")
STOPWORDS = set(stopwords.words('english'))

def Nltk2Word_And_Tag(nltk_tag):
    """
        Input text: a string
        return: string tag such as 'a','v','n','r'
    """
    if nltk_tag.startswith('J'):
        return wordnet.wordnet.ADJ
    elif nltk_tag.startswith('V'):
        return wordnet.wordnet.VERB
    elif nltk_tag.startswith('N'):
        return wordnet.wordnet.NOUN
    elif nltk_tag.startswith('R'):
        return wordnet.wordnet.ADV
    else:        
        return None
    
def Lemmatize_Sentence(sentence):
    """
        Input text: a string 
        return: lemmatized string
    """
    nltk_tagged = nltk.pos_tag(nltk.word_tokenize(sentence))  
    w_n_tagged = map(lambda x: (x[0], Nltk2Word_And_Tag(x[1])), nltk_tagged)
    res_words = []
    for word, tag in w_n_tagged:
        if tag is None: 
            res_words.append(word)
        else:
            res_words.append(lemmatizer.lemmatize(word, tag))
    return " ".join(res_words)

def Stem_Sentence(sentence):
    """
        Input text: a string
        Description: Can be applied for varying the analysis of Classifier
        return: stemmed string
    """
    tokenize_words = nltk.word_tokenize(sentence)
    stem_sents = [stemmer.stem(word) for word in tokenize_words]
    return " ".join(stem_sents)

def Length_Words_Disapproved(sentence,length):
    """
        Input text: a string and int for defining the limit on the length of the words that will be allowed
        return: modified text string
    """
    tokenize_words = nltk.word_tokenize(sentence)
    sent = list(filter(lambda x: len(x) > length,tokenize_words))
    return " ".join(sent) 

def Clean_Text(text,flag):
    """
        Input text: a string and flag for stemming on the current text
        return: modified text string which is lower-cased
    """
    text = text.lower() # lowercase text
    text = REMOVING_NUMBERS.sub(" ", text) # removes the occurences of number such as 2019 or 3valued or 21
    text = BAD_SYMBOLS.sub(" ", text) # delete symbols which are in BAD_SYMBOLS_RE from text
    text = REPLACE_BY_SPACE.sub(" ", text) # replace REPLACE_BY_SPACE_RE symbols by space in text
    text = ' '.join(word for word in text.split() if word not in STOPWORDS) # delete stopwords from text 
    if(flag):
        text = Stem_Sentence(text)
    
    return Lemmatize_Sentence(Length_Words_Disapproved(text,3))

#part of speech tagging of data
def posTagging(x):
    tokenization = word_tokenize(x)
    tagged = nltk.pos_tag(tokenization)
    return tagged

#chunking of data
taggedData = posTagging(data)
def chunkingData(x):
    chunkGram = r"""Chunk: {<RB.?>*<VB.?>*<NNP>+<NN>?}"""
    chunkParser = nltk.RegexpParser(chunkGram)
    chunked = chunkParser.parse(x)
    print (chunked)
    chunked.draw()

#Named Entity Recognition of data
def nerData(x):
    namedEnt = nltk.ne_chunk (x, binary = True)
    print (namedEnt)

# %% [markdown]
# ##Checking the results

# %%
data = Clean_Text(data,1)
data
# Out:
# 'friend miss moon trailer alreadi omgaga sooo gunna dentist sinc supos crown think cheat worri much juuuuuuuuuuuuuuuuussssst chillin sunni work tomorrow tonight hand uniform today miss alreadi hmmmm wonder number must think posit thank hater face weekend suck isnt show australia that feel right awhh complet useless funni twitter feel strang fine listen semison celebr huge roll thunder scari beard grow well year start shaunamanu happi meantim iran wompppp wompp caus follow pretti awesom level write massiv blog tweet myspac comp shut lose fetal posit head hospitol pull golf tourni place think someth yeah bore what wrong pleas tell bother wish could spend rest life serious feeel like shit right realli want sleep nooo hour danc assign finish goodby exam hello alcohol tonight realiz deep geez give girl warn atleast hate athlet appear tear live televis miss think wear skinni jean cute sweater heel realli sure today meet meat horsi move saturday morn need work week realli dont like room bore sick wardrob cant waiit till walk floyd great reliev need scold time like million upload pictur friendster type spaz download viru brother fuck forev fightiin wiit babe write someth last week call someon york offic enough say need even well anyway chri cornel chicago tonight health class joke ginaaa show tonight spiral_galaxi ymptweet realli make look muslim realiti time shall motiv rest week entertain someon complain properli ruptureraptur experiment experi melodi anoth year laker neither magic baddest eveer bathroom clean enjoy task boom boom proud congrat helio though david must hospit five juli palatin tonsil probabl never kati concert friend leav caus stupid love give right harri sunday happi hand quilt hate leysh t9ar5 alway want bend backward work sooooon miss codi booo see foreverr hate allergi hair tomorrow take public poll love much hurt miss earl miss jersey miss first hour sytycd last night find onlin need never think becom second choic think friendli well think manuel basil plant live home church wonder make pizza want harddriv inch guitar anyonefeel gener want want miley tour australia want sleep morn mean popsicl stick head wish could away like squirrel slow send sunshin northern ireland swim today kezbat wish could beach would great shontelle_layn danmerriweath would much happier wall bedroom paint white trust sorri pain caus nebodi take time straighten yall find intercept slope bang head wall math brain head come save realli sick cough cough head airport home christi case feel camp feel bring human right watch world report hope work twitter jona almost funer much time much love grandpa never last quot goodby quot smile sure could want home friend zahra see sinc graduat make happi long night ever momacita bball game grrr phone immedi mobil steal mother want pose church hang girl moro hope movi time sunday plan tomorrow guess mean work present pavel tonight tigersfan cool night thank plea probabl guna soon sinc talkin realli want safina pull lose like david rise back special damn half year away sannesia neighbor need watch mean girl what statu next weekend sorri gigi4462 husband overdos daili dose haterad thank definit throwbi editor review entri decid publish thank need help explain alot heather sequel winona4ev well fuck tell drink give porter stout bring home neighbor trae sweet buy baith suit weave true highli subject tombr actual favorit charact book rishabh whyy much waahhh miss quot quot quot quot quot quot quot quot stand pour rain world summer suck go theyv stitch charg still bleed like waterfal everytim move pictur feel nake train manchest sunday jonasbroth concert must peopl picki mean hour work dice twitter soon becom obsolet wide awak yeah weather last week stink kristi comin say mmmayb take stranger hello frank lampard fine urself stranger alway turnoffword shit suck asylm panel guess back normal life poemsunder140 start shannonelyse1 squarespac brighten never anyth susan boyl didnt well diver good though congratz twe ...

# %%
Lemmatize_Sentence(data)
# Out:
# 'friend miss moon trailer alreadi omgaga sooo gunna dentist sinc supos crown think cheat worri much juuuuuuuuuuuuuuuuussssst chillin sunni work tomorrow tonight hand uniform today miss alreadi hmmmm wonder number must think posit thank hater face weekend suck isnt show australia that feel right awhh complet useless funni twitter feel strang fine listen semison celebr huge roll thunder scari beard grow well year start shaunamanu happi meantim iran wompppp wompp caus follow pretti awesom level write massiv blog tweet myspac comp shut lose fetal posit head hospitol pull golf tourni place think someth yeah bore what wrong pleas tell bother wish could spend rest life serious feeel like shit right realli want sleep nooo hour danc assign finish goodby exam hello alcohol tonight realiz deep geez give girl warn atleast hate athlet appear tear live televis miss think wear skinni jean cute sweater heel realli sure today meet meat horsi move saturday morn need work week realli dont like room bore sick wardrob cant waiit till walk floyd great reliev need scold time like million upload pictur friendster type spaz download viru brother fuck forev fightiin wiit babe write someth last week call someon york offic enough say need even well anyway chri cornel chicago tonight health class joke ginaaa show tonight spiral_galaxi ymptweet realli make look muslim realiti time shall motiv rest week entertain someon complain properli ruptureraptur experiment experi melodi anoth year laker neither magic baddest eveer bathroom clean enjoy task boom boom proud congrat helio though david must hospit five juli palatin tonsil probabl never kati concert friend leav caus stupid love give right harri sunday happi hand quilt hate leysh t9ar5 alway want bend backward work sooooon miss codi booo see foreverr hate allergi hair tomorrow take public poll love much hurt miss earl miss jersey miss first hour sytycd last night find onlin need never think becom second choic think friendli well think manuel basil plant live home church wonder make pizza want harddriv inch guitar anyonefeel gener want want miley tour australia want sleep morn mean popsicl stick head wish could away like squirrel slow send sunshin northern ireland swim today kezbat wish could beach would great shontelle_layn danmerriweath would much happier wall bedroom paint white trust sorri pain caus nebodi take time straighten yall find intercept slope bang head wall math brain head come save realli sick cough cough head airport home christi case feel camp feel bring human right watch world report hope work twitter jona almost funer much time much love grandpa never last quot goodby quot smile sure could want home friend zahra see sinc graduat make happi long night ever momacita bball game grrr phone immedi mobil steal mother want pose church hang girl moro hope movi time sunday plan tomorrow guess mean work present pavel tonight tigersfan cool night thank plea probabl guna soon sinc talkin realli want safina pull lose like david rise back special damn half year away sannesia neighbor need watch mean girl what statu next weekend sorri gigi4462 husband overdos daili dose haterad thank definit throwbi editor review entri decid publish thank need help explain alot heather sequel winona4ev well fuck tell drink give porter stout bring home neighbor trae sweet buy baith suit weave true highli subject tombr actual favorit charact book rishabh whyy much waahhh miss quot quot quot quot quot quot quot quot stand pour rain world summer suck go theyv stitch charg still bleed like waterfal everytim move pictur feel nake train manchest sunday jonasbroth concert must peopl picki mean hour work dice twitter soon becom obsolet wide awak yeah weather last week stink kristi comin say mmmayb take stranger hello frank lampard fine urself stranger alway turnoffword shit suck asylm panel guess back normal life poemsunder140 start shannonelyse1 squarespac brighten never anyth susan boyl didnt well diver good though congratz twe ...

# %%
posTagging(data)
# Out:
# [('friend', 'NN'),
#  ('miss', 'VBZ'),
#  ('moon', 'RB'),
#  ('trailer', 'JJ'),
#  ('alreadi', 'NN'),
#  ('omgaga', 'NN'),
#  ('sooo', 'NN'),
#  ('gunna', 'NN'),
#  ('dentist', 'NN'),
#  ('sinc', 'NN'),
#  ('supos', 'VBD'),
#  ('crown', 'JJ'),
#  ('think', 'NN'),
#  ('cheat', 'NN'),
#  ('worri', 'VBP'),
#  ('much', 'JJ'),
#  ('juuuuuuuuuuuuuuuuussssst', 'NN'),
#  ('chillin', 'NN'),
#  ('sunni', 'NN'),
#  ('work', 'NN'),
#  ('tomorrow', 'NN'),
#  ('tonight', 'JJ'),
#  ('hand', 'NN'),
#  ('uniform', 'NN'),
#  ('today', 'NN'),
#  ('miss', 'VBP'),
#  ('alreadi', 'NN'),
#  ('hmmmm', 'NN'),
#  ('wonder', 'VBP'),
#  ('number', 'NN'),
#  ('must', 'MD'),
#  ('think', 'VB'),
#  ('posit', 'NN'),
#  ('thank', 'NN'),
#  ('hater', 'NN'),
#  ('face', 'NN'),
#  ('weekend', 'NN'),
#  ('suck', 'VBD'),
#  ('isnt', 'JJ'),
#  ('show', 'NN'),
#  ('australia', 'VBZ'),
#  ('that', 'IN'),
#  ('feel', 'VB'),
#  ('right', 'JJ'),
#  ('awhh', 'NN'),
#  ('complet', 'NN'),
#  ('useless', 'JJ'),
#  ('funni', 'NN'),
#  ('twitter', 'NN'),
#  ('feel', 'NN'),
#  ('strang', 'VBD'),
#  ('fine', 'JJ'),
#  ('listen', 'JJ'),
#  ('semison', 'NN'),
#  ('celebr', 'NN'),
#  ('huge', 'JJ'),
#  ('roll', 'NN'),
#  ('thunder', 'NN'),
#  ('scari', 'NN'),
#  ('beard', 'NN'),
#  ('grow', 'NN'),
#  ('well', 'RB'),
#  ('year', 'NN'),
#  ('start', 'NN'),
#  ('shaunamanu', 'NN'),
#  ('happi', 'NN'),
#  ('meantim', 'NN'),
#  ('iran', 'NN'),
#  ('wompppp', 'NN'),
#  ('wompp', 'NN'),
#  ('caus', 'NN'),
#  ('follow', 'VBP'),
#  ('pretti', 'NNS'),
#  ('awesom', 'VBP'),
#  ('level', 'JJ'),
#  ('write', 'JJ'),
#  ('massiv', 'NN'),
#  ('blog', 'NN'),
#  ('tweet', 'NN'),
#  ('myspac', 'NN'),
#  ('comp', 'NN'),
#  ('shut', 'VBD'),
#  ('lose', 'JJ'),
#  ('fetal', 'JJ'),
#  ('posit', 'NN'),
#  ('head', 'NN'),
#  ('hospitol', 'NN'),
#  ('pull', 'JJ'),
#  ('golf', 'NN'),
#  ('tourni', 'JJ'),
#  ('place', 'NN'),
#  ('think', 'VBP'),
#  ('someth', 'VBN'),
#  ('yeah', 'RB'),
#  ('bore', 'VB'),
#  ('what', 'WP'),
#  ('wrong', 'JJ'),
#  ('pleas', 'RB'),
#  ('tell', 'VBP'),
#  ('bother', 'RB'),
#  ('wish', 'JJ'),
#  ('could', 'MD'),
#  ('spend', 'VB'),
#  ('rest', 'JJ'),
#  ('life', 'NN'),
#  ('serious', 'JJ'),
#  ('feeel', 'NN'),
#  ('like', 'IN'),
#  ('shit', 'NN'),
#  ('right', 'RB'),
#  ('realli', 'NN'),
#  ('want', 'VBP'),
#  ('sleep', 'JJ'),
#  ('nooo', 'FW'),
#  ('hour', 'NN'),
#  ('danc', 'NN'),
#  ('assign', 'NN'),
#  ('finish', 'JJ'),
#  ('goodby', 'NN'),
#  ('exam', 'NN'),
#  ('hello', 'NN'),
#  ('alcohol', 'NN'),
#  ('tonight', 'NN'),
#  ('realiz', 'NN'),
#  ('deep', 'JJ'),
#  ('geez', 'NN'),
#  ('give', 'VBP'),
#  ('girl', 'NN'),
#  ('warn', 'NN'),
#  ('atleast', 'NN'),
#  ('hate', 'NN'),
#  ('athlet', 'NN'),
#  ('appear', 'VBP'),
#  ('tear', 'IN'),
#  ('live', 'JJ'),
#  ('televis', 'NN'),
#  ('miss', 'NN'),
#  ('think', 'VBP'),
#  ('wear', 'IN'),
#  ('skinni', 'JJ'),
#  ('jean', 'JJ'),
#  ('cute', 'NN'),
#  ('sweater', 'NN'),
#  ('heel', 'NN'),
#  ('realli', 'NN'),
#  ('sure', 'JJ'),
#  ('today', 'NN'),
#  ('meet', 'NN'),
#  ('meat', 'NN'),
#  ('horsi', 'VBD'),
#  ('move', 'NN'),
#  ('saturday', 'NN'),
#  ('morn', 'VBD'),
#  ('need', 'JJ'),
#  ('work', 'NN'),
#  ('week', 'NN'),
#  ('realli', 'VBP'),
#  ('dont', 'NN'),
#  ('like', 'IN'),
#  ('room', 'NN'),
#  ('bore', 'NN'),
#  ('sick', 'JJ'),
#  ('wardrob', 'NN'),
#  ('cant', 'NN'),
#  ('waiit', 'NN'),
#  ('till', 'NN'),
#  ('walk', 'VBP'),
#  ('floyd', 'RB'),
#  ('great', 'JJ'),
#  ('reliev', 'NNS'),
#  ('need', 'VBP'),
#  ('scold', 'JJ'),
#  ('time', 'NN'),
#  ('like', 'IN'),
#  ('million', 'CD'),
#  ('upload', 'JJ'),
#  ('pictur', 'NN'),
#  ('friendster', 'NN'),
#  ('type', 'NN'),
#  ('spaz', 'NN'),
#  ('download', 'NN'),
#  ('viru', 'NN'),
#  ('brother', 'NN'),
#  ('fuck', 'VBD'),
#  ('forev', 'JJ'),
#  ('fightiin', 'NN'),
#  ('wiit', 'NN'),
#  ('babe', 'NN'),
#  ('write', 'VBP'),
#  ('someth', 'VBN'),
#  ('last', 'JJ'),
#  ('week', 'NN'),
#  ('call', 'NN'),
#  ('someon', 'NN'),
#  ('york', 'NN'),
#  ('offic', 'JJ'),
#  ('enough', 'RB'),
#  ('say', 'VBP'),
#  ('need', 'MD'),
#  ('even', 'RB'),
#  ('well', 'VB'),
#  ('anyway', 'RB'),
#  ('chri', 'JJ'),
#  ('cornel', 'NNS'),
#  ('chicago', 'RB'),
#  ('tonight', 'VBD'),
#  ('health', 'NN'),
#  ('class', 'NN'),
#  ('joke', 'NN'),
#  ('ginaaa', 'NN'),
#  ('show', 'NN'),
#  ('tonight', 'VBD'),
#  ('spiral_galaxi', 'JJ'),
#  ('ymptweet', 'NN'),
#  ('realli', 'NNS'),
#  ('make', 'VBP'),
#  ('look', 'NN'),
#  ('muslim', 'NN'),
#  ('realiti', 'NN'),
#  ('time', 'NN'),
#  ('shall', 'MD'),
#  ('motiv', 'VB'),
#  ('rest', 'NN'),
#  ('week', 'NN'),
#  ('entertain', 'VBP'),
#  ('someon', 'NN'),
#  ('complain', 'NN'),
#  ('properli', 'NN'),
#  ('ruptureraptur', 'NN'),
#  ('experiment', 'NN'),
#  ('experi', 'NN'),
#  ('melodi', 'NN'),
#  ('anoth', 'DT'),
#  ('year', 'NN'),
#  ('laker', 'NN'),
#  ('neither', 'CC'),
#  ('magic', 'JJ'),
#  ('baddest', 'JJS'),
#  ('eveer', 'NN'),
#  ('bathroom', 'NN'),
#  ('clean', 'JJ'),
#  ('enjoy', 'NN'),
#  ('task', 'NN'),
#  ('boom', 'NN'),
#  ('boom', 'NN'),
#  ('proud', 'JJ'),
#  ('congrat', 'NN'),
#  ('helio', 'NN'),
#  ('though', 'IN'),
#  ('david', 'JJ'),
#  ('must', 'MD'),
#  ('hospit', 'VB'),
#  ('five', 'CD'),
#  ('juli', 'NNS'),
#  ('palatin', 'NN'),
#  ('tonsil', 'NN'),
#  ('probabl', 'NN'),
#  ('never', 'RB'),
#  ('kati', 'VBD'),
#  ('concert', 'JJ'),
#  ('friend', 'NN'),
#  ('leav', 'NN'),
#  ('caus', 'NN'),
#  ('stupid', 'JJ'),
#  ('love', 'VBP'),
#  ('give', 'VB'),
#  ('right', 'JJ'),
#  ('harri', 'NN'),
#  ('sunday', 'NN'),
#  ('happi', 'VBD'),
#  ('hand', 'NN'),
#  ('quilt', 'NN'),
#  ('hate', 'NN'),
#  ('leysh', 'NN'),
#  ('t9ar5', 'VBP'),
#  ('alway', 'RB'),
#  ('want', 'VBP'),
#  ('bend', 'JJ'),
#  ('backward', 'NN'),
#  ('work', 'NN'),
#  ('sooooon', 'NN'),
#  ('miss', 'JJ'),
#  ('codi', 'NN'),
#  ('booo', 'NN'),
#  ('see', 'VBP'),
#  ('foreverr', 'JJ'),
#  ('hate', 'NN'),
#  ('allergi', 'NNS'),
#  ('hair', 'NN'),
#  ('tomorrow', 'NN'),
#  ('take', 'VB'),
#  ('public', 'JJ'),
#  ('poll', 'NN'),
#  ('love', 'RB'),
#  ('much', 'JJ'),
#  ('hurt', 'NN'),
#  ('miss', 'VBD'),
#  ('earl', 'JJ'),
#  ('miss', 'NN'),
#  ('jersey', 'NN'),
#  ('miss', 'NN'),
#  ('first', 'RB'),
#  ('hour', 'NN'),
#  ('sytycd', 'NN'),
#  ('last', 'JJ'),
#  ('night', 'NN'),
#  ('find', 'VBP'),
#  ('onlin', 'JJ'),
#  ('need', 'VBP'),
#  ('never', 'RB'),
#  ('think', 'VBP'),
#  ('becom', 'JJ'),
#  ('second', 'JJ'),
#  ('choic', 'NN'),
#  ('think', 'VBP'),
#  ('friendli', 'RB'),
#  ('well', 'RB'),
#  ('think', 'VB'),
#  ('manuel', 'NN'),
#  ('basil', 'NN'),
#  ('plant', 'NN'),
#  ('live', 'JJ'),
#  ('home', 'NN'),
#  ('church', 'NN'),
#  ('wonder', 'VBP'),
#  ('make', 'VBP'),
#  ('pizza', 'NN'),
#  ('want', 'VBP'),
#  ('harddriv', 'NN'),
#  ('inch', 'NN'),
#  ('guitar', 'NN'),
#  ('anyonefeel', 'VBP'),
#  ('gener', 'NN'),
#  ('want', 'VBP'),
#  ('want', 'JJ'),
#  ('miley', 'FW'),
#  ('tour', 'NNS'),
#  ('australia', 'VBP'),
#  ('want', 'JJ'),
#  ('sleep', 'NN'),
#  ('morn', 'JJ'),
#  ('mean', 'JJ'),
#  ('popsicl', 'NN'),
#  ('stick', 'JJ'),
#  ('head', 'NN'),
#  ('wish', 'NN'),
#  ('could', 'MD'),
#  ('away', 'RB'),
#  ('like', 'IN'),
#  ('squirrel', 'NN'),
#  ('slow', 'JJ'),
#  ('send', 'NN'),
#  ('sunshin', 'NN'),
#  ('northern', 'JJ'),
#  ('ireland', 'NN'),
#  ('swim', 'NN'),
#  ('today', 'NN'),
#  ('kezbat', 'VBP'),
#  ('wish', 'NN'),
#  ('could', 'MD'),
#  ('beach', 'VB'),
#  ('would', 'MD'),
#  ('great', 'JJ'),
#  ('shontelle_layn', 'JJ'),
#  ('danmerriweath', 'NN'),
#  ('would', 'MD'),
#  ('much', 'RB'),
#  ('happier', 'VB'),
#  ('wall', 'NN'),
#  ('bedroom', 'NN'),
#  ('paint', 'NN'),
#  ('white', 'JJ'),
#  ('trust', 'NN'),
#  ('sorri', 'NN'),
#  ('pain', 'NN'),
#  ('caus', 'JJ'),
#  ('nebodi', 'NNS'),
#  ('take', 'VBP'),
#  ('time', 'NN'),
#  ('straighten', 'VB'),
#  ('yall', 'JJ'),
#  ('find', 'VB'),
#  ('intercept', 'JJ'),
#  ('slope', 'NN'),
#  ('bang', 'NNS'),
#  ('head', 'VBP'),
#  ('wall', 'JJ'),
#  ('math', 'NN'),
#  ('brain', 'NN'),
#  ('head', 'NN'),
#  ('come', 'VBP'),
#  ('save', 'VBP'),
#  ('realli', 'VBN'),
#  ('sick', 'JJ'),
#  ('cough', 'NN'),
#  ('cough', 'NN'),
#  ('head', 'NN'),
#  ('airport', 'NN'),
#  ('home', 'NN'),
#  ('christi', 'NN'),
#  ('case', 'NN'),
#  ('feel', 'VB'),
#  ('camp', 'NNS'),
#  ('feel', 'VB'),
#  ('bring', 'VBG'),
#  ('human', 'JJ'),
#  ('right', 'JJ'),
#  ('watch', 'NN'),
#  ('world', 'NN'),
#  ('report', 'NN'),
#  ('hope', 'VBP'),
#  ('work', 'NN'),
#  ('twitter', 'NN'),
#  ('jona', 'NN'),
#  ('almost', 'RB'),
#  ('funer', 'RB'),
#  ('much', 'JJ'),
#  ('time', 'NN'),
#  ('much', 'JJ'),
#  ('love', 'NN'),
#  ('grandpa', 'NN'),
#  ('never', 'RB'),
#  ('last', 'JJ'),
#  ('quot', 'JJ'),
#  ('goodby', 'NN'),
#  ('quot', 'NN'),
#  ('smile', 'JJ'),
#  ('sure', 'NN'),
#  ('could', 'MD'),
#  ('want', 'VB'),
#  ('home', 'NN'),
#  ('friend', 'NN'),
#  ('zahra', 'NN'),
#  ('see', 'VBP'),
#  ('sinc', 'JJ'),
#  ('graduat', 'NNS'),
#  ('make', 'VBP'),
#  ('happi', 'NN'),
#  ('long', 'RB'),
#  ('night', 'NN'),
#  ('ever', 'RB'),
#  ('momacita', 'RB'),
#  ('bball', 'JJ'),
#  ('game', 'NN'),
#  ('grrr', 'NN'),
#  ('phone', 'NN'),
#  ('immedi', 'NN'),
#  ('mobil', 'NN'),
#  ('steal', 'VBP'),
#  ('mother', 'NN'),
#  ('want', 'VBP'),
#  ('pose', 'JJ'),
#  ('church', 'NN'),
#  ('hang', 'NN'),
#  ('girl', 'NN'),
#  ('moro', 'FW'),
#  ('hope', 'NN'),
#  ('movi', 'NN'),
#  ('time', 'NN'),
#  ('sunday', 'JJ'),
#  ('plan', 'NN'),
#  ('tomorrow', 'NN'),
#  ('guess', 'JJ'),
#  ('mean', 'JJ'),
#  ('work', 'NN'),
#  ('present', 'JJ'),
#  ('pavel', 'NN'),
#  ('tonight', 'NN'),
#  ('tigersfan', 'NN'),
#  ('cool', 'JJ'),
#  ('night', 'NN'),
#  ('thank', 'NN'),
#  ('plea', 'NN'),
#  ('probabl', 'NN'),
#  ('guna', 'NN'),
#  ('soon', 'RB'),
#  ('sinc', 'JJ'),
#  ('talkin', 'JJ'),
#  ('realli', 'NN'),
#  ('want', 'VBP'),
#  ('safina', 'JJ'),
#  ('pull', 'NN'),
#  ('lose', 'VBP'),
#  ('like', 'IN'),
#  ('david', 'NN'),
#  ('rise', 'NN'),
#  ('back', 'RB'),
#  ('special', 'JJ'),
#  ('damn', 'NN'),
#  ('half', 'JJ'),
#  ('year', 'NN'),
#  ('away', 'RB'),
#  ('sannesia', 'JJ'),
#  ('neighbor', 'NNS'),
#  ('need', 'VBP'),
#  ('watch', 'JJ'),
#  ('mean', 'VB'),
#  ('girl', 'VB'),
#  ('what', 'WP'),
#  ('statu', 'JJ'),
#  ('next', 'JJ'),
#  ('weekend', 'NN'),
#  ('sorri', 'NN'),
#  ('gigi4462', 'JJ'),
#  ('husband', 'NN'),
#  ('overdos', 'NN'),
#  ('daili', 'NN'),
#  ('dose', 'JJ'),
#  ('haterad', 'NN'),
#  ('thank', 'NN'),
#  ('definit', 'NN'),
#  ('throwbi', 'NN'),
#  ('editor', 'NN'),
#  ('review', 'NN'),
#  ('entri', 'VBP'),
#  ('decid', 'JJ'),
#  ('publish', 'JJ'),
#  ('thank', 'NN'),
#  ('need', 'NN'),
#  ('help', 'NN'),
#  ('explain', 'VB'),
#  ('alot', 'IN'),
#  ('heather', 'JJR'),
#  ('sequel', 'NN'),
#  ('winona4ev', 'NN'),
#  ('well', 'RB'),
#  ('fuck', 'RB'),
#  ('tell', 'VB'),
#  ('drink', 'VB'),
#  ('give', 'JJ'),
#  ('porter', 'NN'),
#  ('stout', 'NN'),
#  ('bring', 'VBP'),
#  ('home', 'NN'),
#  ('neighbor', 'NN'),
#  ('trae', 'NN'),
#  ('sweet', 'JJ'),
#  ('buy', 'NN'),
#  ('baith', 'NN'),
#  ('suit', 'NN'),
#  ('weave', 'VBP'),
#  ('true', 'JJ'),
#  ('highli', 'NN'),
#  ('subject', 'JJ'),
#  ('tombr', 'NN'),
#  ('actual', 'JJ'),
#  ('favorit', 'NN'),
#  ('charact', 'NN'),
#  ('book', 'NN'),
#  ('rishabh', 'NN'),
#  ('whyy', 'RB'),
#  ('much', 'JJ'),
#  ('waahhh', 'NN'),
#  ('miss', 'NN'),
#  ('quot', 'NN'),
#  ('quot', 'NN'),
#  ('quot', 'NN'),
#  ('quot', 'NN'),
#  ('quot', 'NN'),
#  ('quot', 'NN'),
#  ('quot', 'NN'),
#  ('quot', 'NN'),
#  ('stand', 'VBP'),
#  ('pour', 'NN'),
#  ('rain', 'NN'),
#  ('world', 'NN'),
#  ('summer', 'NN'),
#  ('suck', 'NN'),
#  ('go', 'VBP'),
#  ('theyv', 'JJ'),
#  ('stitch', 'NN'),
#  ('charg', 'NN'),
#  ('still', 'RB'),
#  ('bleed', 'VBN'),
#  ('like', 'IN'),
#  ('waterfal', 'NN'),
#  ('everytim', 'NN'),
#  ('move', 'NN'),
#  ('pictur', 'NN'),
#  ('feel', 'NN'),
#  ('nake', 'RB'),
#  ('train', 'JJ'),
#  ('manchest', 'JJS'),
#  ('sunday', 'JJ'),
#  ('jonasbroth', 'DT'),
#  ('concert', 'NN'),
#  ('must', 'MD'),
#  ('peopl', 'VB'),
#  ('picki', 'JJ'),
#  ('mean', 'VB'),
#  ('hour', 'NN'),
#  ('work', 'NN'),
#  ('dice', 'NN'),
#  ('twitter', 'RB'),
#  ('soon', 'RB'),
#  ('becom', 'JJ'),
#  ('obsolet', 'NN'),
#  ('wide', 'JJ'),
#  ('awak', 'NN'),
#  ('yeah', 'NN'),
#  ('weather', 'NN'),
#  ('last', 'JJ'),
#  ('week', 'NN'),
#  ('stink', 'VBP'),
#  ('kristi', 'NN'),
#  ('comin', 'NNS'),
#  ('say', 'VBP'),
#  ('mmmayb', 'NNS'),
#  ('take', 'VBP'),
#  ('stranger', 'NN'),
#  ('hello', 'NN'),
#  ('frank', 'JJ'),
#  ('lampard', 'JJ'),
#  ('fine', 'NN'),
#  ('urself', 'JJ'),
#  ('stranger', 'NN'),
#  ('alway', 'NN'),
#  ('turnoffword', 'NN'),
#  ('shit', 'VBD'),
#  ('suck', 'JJ'),
#  ('asylm', 'JJ'),
#  ('panel', 'NN'),
#  ('guess', 'NN'),
#  ('back', 'RB'),
#  ('normal', 'JJ'),
#  ('life', 'NN'),
#  ('poemsunder140', 'JJ'),
#  ('start', 'NN'),
#  ('shannonelyse1', 'NN'),
#  ('squarespac', 'NN'),
#  ('brighten', 'VBD'),
#  ('never', 'RB'),
#  ('anyth', 'VBN'),
#  ('susan', 'JJ'),
#  ('boyl', 'NN'),
#  ('didnt', 'NN'),
#  ('well', 'RB'),
#  ('diver', 'RB'),
#  ('good', 'JJ'),
#  ('though', 'IN'),
#  ('congratz', 'JJ'),
#  ('twenty20', 'NN'),
#  ('believ', 'NN'),
#  ('enough', 'RB'),
#  ('goooood', 'NN'),
#  ('times', 'NNS'),
#  ('graduat', 'VBP'),
#  ('quot', 'JJ'),
#  ('vandal', 'JJ'),
#  ('paint', 'NN'),
#  ('swastika', 'VBD'),
#  ('home', 'NN'),
#  ('author', 'NN'),
#  ('lesbian', 'JJ'),
#  ('church', 'NN'),
#  ('stori', 'NN'),
#  ('napl', 'NN'),
#  ('daili', 'JJ'),
#  ('news', 'NN'),
#  ('quot', 'NN'),
#  ('quot', 'NN'),
#  ('unknown', 'JJ'),
#  ('error', 'NN'),
#  ('occur', 'VBP'),
#  ('quot', 'NN'),
#  ('iphon', 'NN'),
#  ('fail', 'VBP'),
#  ('quot', 'NN'),
#  ('expert', 'NN'),
#  ('homer', 'NN'),
#  ('predict', 'VBP'),
#  ('eagl', 'NN'),
#  ('giant', 'NN'),
#  ('quot', 'NN'),
#  ('know', 'VBP'),
#  ('hungri', 'NN'),
#  ('outsid', 'NN'),
#  ('balconi', 'NN'),
#  ('quot', 'VBP'),
#  ('quot', 'NN'),
#  ('want', 'VBP'),
#  ('drive', 'NN'),
#  ('quot', 'NN'),
#  ('quot', 'NN'),
#  ('femal', 'JJ'),
#  ('internet', 'NN'),
#  ('entrepreneur', 'NN'),
#  ('know', 'VBP'),
#  ('start', 'NN'),
#  ('grow', 'VB'),
#  ('busi', 'JJ'),
#  ('next', 'JJ'),
#  ('woman', 'NN'),
#  ('quot', 'NN'),
#  ('quot', 'NN'),
#  ('truth', 'NN'),
#  ('hide', 'NN'),
#  ('quot', 'NN'),
#  ('patita', 'NN'),
#  ('missmarian', 'JJ'),
#  ('paramor', 'NN'),
#  ('decod', 'NN'),
#  ('daninho502', 'NN'),
#  ('quot', 'NN'),
#  ('turn', 'VBP'),
#  ('head', 'NN'),
#  ('feel', 'VB'),
#  ('insid', 'JJ'),
#  ('admit', 'NN'),
#  ('quot', 'NN'),
#  ('liter', 'NN'),
#  ('feel', 'NN'),
#  ('quot', 'RB'),
#  ('well', 'RB'),
#  ('truth', 'RB'),
#  ('miss', 'JJ'),
#  ('quot', 'NN'),
#  ('coldplay', 'NN'),
#  ('tear', 'NN'),
#  ('today', 'NN'),
#  ('last', 'JJ'),
#  ('summer', 'NN'),
#  ('break', 'NN'),
#  ('tomorrow', 'NN'),
#  ('sigh', 'JJ'),
#  ('unsur', 'JJ'),
#  ('annoy', 'NN'),
#  ('designrel', 'NN'),
#  ('design', 'NN'),
#  ('galleri', 'JJ'),
#  ('exhibit', 'NN'),
#  ('postcard', 'NN'),
#  ('mailer', 'NN'),
#  ('extinct', 'JJ'),
#  ('beautifulylost', 'NN'),
#  ('miss', 'NN'),
#  ('harri', 'NN'),
#  ('potter', 'NN'),
#  ('come', 'VBP'),
#  ('leav', 'NN'),
#  ('vietnam', 'NN'),
#  ('juli', 'NN'),
#  ('hummin', 'NN'),
#  ('quot', 'NN'),
#  ('shut', 'VBD'),
#  ('money', 'NN'),
#  ('mouth', 'NN'),
#  ('quot', 'VBP'),
#  ('headin', 'NN'),
#  ('realiti', 'NNS'),
#  ('cheer', 'VBP'),
#  ('twitter', 'NN'),
#  ('world', 'NN'),
#  ('sigh', 'NN'),
#  ('cant', 'NN'),
#  ('love', 'NN'),
#  ('someon', 'NN'),
#  ('love', 'VBP'),
#  ('back', 'RB'),
#  ('like', 'IN'),
#  ('stalker', 'NN'),
#  ('statu', 'NN'),
#  ('divorc', 'NN'),
#  ('move', 'NN'),
#  ('triniti', 'NN'),
#  ('back', 'RB'),
#  ('lookin', 'JJ'),
#  ('around', 'IN'),
#  ('reason', 'NN'),
#  ('awak', 'NN'),
#  ('littl', 'NN'),
#  ('aiqht', 'NN'),
#  ('goodniqht', 'NN'),
#  ('neena', 'JJ'),
#  ('malcolm', 'NN'),
#  ('chais', 'NN'),
#  ('jlew', 'NN'),
#  ('love', 'VB'),
#  ('much', 'JJ'),
#  ('triiiiiii', 'NN'),
#  ('even', 'RB'),
#  ('chais', 'VBP'),
#  ('laughter', 'JJR'),
#  ('wantt', 'NN'),
#  ('hiim', 'NN'),
#  ('badd', 'NN'),
#  ('watch', 'NN'),
#  ('shop', 'NN'),
#  ('trent', 'NN'),
#  ('hope', 'VBP'),
#  ('need', 'VBP'),
#  ('best', 'JJS'),
#  ('friend', 'JJ'),
#  ('weird', 'NN'),
#  ('encount', 'NN'),
#  ('mani', 'NN'),
#  ('homeless', 'NN'),
#  ('creep', 'NN'),
#  ('walk', 'VBP'),
#  ('home', 'NN'),
#  ('tonight', 'NN'),
#  ('awesom', 'NN'),
#  ('realli', 'NN'),
#  ('rain', 'VBP'),
#  ('truck', 'NN'),
#  ('race', 'NN'),
#  ('feel', 'NN'),
#  ('wors', 'NNS'),
#  ('feel', 'VBP'),
#  ('pain', 'RB'),
#  ('happi', 'JJ'),
#  ('time', 'NN'),
#  ('confus', 'NN'),
#  ('choco', 'NN'),
#  ('best', 'JJS'),
#  ('shirt', 'NN'),
#  ('panti', 'NN'),
#  ('celulit', 'NN'),
#  ('turn', 'VBP'),
#  ('back', 'RB'),
#  ('north', 'JJ'),
#  ('bodi', 'NN'),
#  ('line', 'NN'),
#  ('miss', 'VBP'),
#  ('design', 'NN'),
#  ('council', 'NN'),
#  ('design', 'NN'),
#  ('tech', 'NN'),
#  ('transfer', 'NN'),
#  ('event', 'NN'),
#  ('everyth', 'RB'),
#  ('hard', 'JJ'),
#  ('bueno', 'NN'),
#  ('good', 'JJ'),
#  ('good', 'JJ'),
#  ('night', 'NN'),
#  ('beach', 'NN'),
#  ('scoob', 'NN'),
#  ('still', 'RB'),
#  ('phone', 'NN'),
#  ('give', 'JJ'),
#  ('give', 'NN'),
#  ('want', 'VBP'),
#  ('move', 'NN'),
#  ('amaz', 'NN'),
#  ('night', 'NN'),
#  ('night', 'NN'),
#  ('twit', 'NN'),
#  ('miss', 'VBP'),
#  ('canaver', 'NN'),
#  ('nation', 'NN'),
#  ('seashor', 'NN'),
#  ('progress', 'NN'),
#  ('product', 'NN'),
#  ('depart', 'NN'),
#  ('quot', 'NN'),
#  ('upriz', 'JJ'),
#  ('quot', 'NN'),
#  ('that', 'WDT'),
#  ('prioriti', 'VBZ'),
#  ('head', 'NN'),
#  ('beat', 'NN'),
#  ('reach', 'VBP'),
#  ('taylorrhick', 'JJ'),
#  ('enjoy', 'NN'),
#  ('chicago', 'NN'),
#  ('venu', 'NN'),
#  ('alway', 'RB'),
#  ('cool', 'JJ'),
#  ('shine', 'NN'),
#  ('everywher', 'RB'),
#  ('know', 'JJ'),
#  ('time', 'NN'),
#  ('everyon', 'JJ'),
#  ('train', 'NN'),
#  ('crash', 'NN'),
#  ('thestreetforc', 'NN'),
#  ('sixty5day', 'JJ'),
#  ('make', 'VBP'),
#  ('smile', 'JJ'),
#  ('adamisacson', 'NN'),
#  ('first', 'RB'),
#  ('week', 'NN'),
#  ('child', 'NN'),
#  ('watch', 'NN'),
#  ('quot', 'NN'),
#  ('nanci', 'JJ'),
#  ('grac', 'NN'),
#  ('adbert', 'NN'),
#  ('quot', 'NN'),
#  ('video', 'NN'),
#  ('woodi', 'NN'),
#  ('woodpeck', 'NN'),
#  ('barber', 'NNP'),
#  ('sevil', 'VBZ'),
#  ('great', 'JJ'),
#  ('klitoria', 'NNS'),
#  ('wish', 'JJ'),
#  ('alexrauchman', 'NN'),
#  ('happi', 'NN'),
#  ('stay', 'VBP'),
#  ('around', 'IN'),
#  ('drexel', 'NN'),
#  ('fabul', 'NN'),
#  ('univers', 'NNS'),
#  ('proud', 'VBP'),
#  ('yeah', 'RB'),
#  ('alvinkschneid', 'JJ'),
#  ('happen', 'VB'),
#  ('angel', 'JJ'),
#  ('demon', 'JJ'),
#  ('lion', 'NN'),
#  ('tiger', 'NN'),
#  ('bear', 'NN'),
#  ('americanwomannn', 'RB'),
#  ('well', 'RB'),
#  ('sure', 'JJ'),
#  ('minim', 'JJ'),
#  ('impact', 'NN'),
#  ('ange_black', 'NN'),
#  ('sween', 'NN'),
#  ('call', 'NN'),
#  ('voltron', 'NN'),
#  ('wait', 'NN'),
#  ('manner', 'NN'),
#  ('baileygenin', 'NN'),
#  ('charlottegc', 'NN'),
#  ('chloelunn', 'NN'),
#  ('meganmcdowel', 'NN'),
#  ('codinghorror', 'NN'),
#  ('three', 'CD'),
#  ('extern', 'JJ'),
#  ('monitor', 'NN'),
#  ('laptop', 'JJ'),
#  ('win7rc', 'NN'),
#  ('x1080', 'NNP'),
#  ('x1024', 'NNP'),
#  ('copicmark', 'NN'),
#  ('quot', 'NN'),
#  ('facebook', 'NN'),
#  ('copic', 'NN'),
#  ('marker', 'NN'),
#  ('cool', 'JJ'),
#  ('cool', 'JJ'),
#  ('mayb', 'NN'),
#  ('send', 'VB'),
#  ('cool', 'JJ'),
#  ('crewislif', 'NN'),
#  ('want', 'VBP'),
#  ('start', 'NN'),
#  ('morn', 'NN'),
#  ('later', 'RB'),
#  ('york', 'NN'),
#  ('californian', 'JJ'),
#  ('even', 'RB'),
#  ('well', 'RB'),
#  ('cybervenu', 'VB'),
#  ('any1', 'JJ'),
#  ('find', 'VBP'),
#  ('dandeliona', 'JJ'),
#  ('make', 'VBP'),
#  ('fettucini', 'JJ'),
#  ('garlic', 'JJ'),
#  ('bread', 'NN'),
#  ('danreg', 'NN'),
#  ('tell', 'NN'),
#  ('pfont', 'NNS'),
#  ('say', 'VBP'),
#  ('happi', 'JJ'),
#  ('bday', 'JJ'),
#  ('darcy_lussi', 'NN'),
#  ('lkramm', 'NN'),
#  ('go', 'VBP'),
#  ('work', 'NN'),
#  ('last', 'JJ'),
#  ('year', 'NN'),
#  ('pant', 'NN'),
#  ('iron', 'NN'),
#  ('last', 'JJ'),
#  ('work', 'NN'),
#  ('dirtyrose17', 'NN'),
#  ('tell', 'NN'),
#  ('would', 'MD'),
#  ('sweep', 'VB'),
#  ('haha', 'NN'),
#  ('dreamingspir', 'NN'),
#  ('mani', 'NN'),
#  ('scienc', 'NN'),
#  ('cartoon', 'NN'),
#  ('em91', 'NN'),
#  ('edinburgh', 'NN'),
#  ('fring', 'VBG'),
#  ('week', 'NN'),
#  ('away', 'RB'),
#  ('need', 'VBP'),
#  ('moni', 'JJ'),
#  ('elliott', 'JJ'),
#  ('angryfeet', 'NN'),
#  ('blame', 'NN'),
#  ('howliet', 'JJ'),
#  ...]

# %%
chunkingData(taggedData)
# Out:
# (S
#   is/VBZ
#   so/RB
#   sad/JJ
#   for/IN
#   my/PRP$
#   (Chunk APL/NNP friend/NN)
#   .../:
#   .../:
#   .../:
#   .../:
#   ./.
#   ,/,
#   I/PRP
#   missed/VBD
#   the/DT
#   (Chunk New/NNP Moon/NNP trailer/NN)
#   .../:
#   ,/,
#   omg/VB
#   its/PRP$
#   already/RB
#   7/CD
#   30/CD
#   (Chunk O/NNP)
#   ,/,
#   (Chunk ../NNP Omgaga/NNP)
#   ./.
#   (Chunk Im/NNP)
#   sooo/VBD
#   im/JJ
#   gunna/NN
#   (Chunk CRy/NNP)
#   ./.
#   I/PRP
#   ve/VBP
#   been/VBN
#   at/IN
#   this/DT
#   dentist/NN
#   since/IN
#   11../CD
#   I/PRP
#   was/VBD
#   suposed/VBN
#   2/CD
#   just/RB
#   get/VB
#   a/DT
#   crown/NN
#   put/VBD
#   on/IN
#   30mins/CD
#   .../:
#   ,/,
#   i/JJ
#   think/VBP
#   mi/JJ
#   bf/NN
#   is/VBZ
#   cheating/VBG
#   on/IN
#   me/PRP
#   (Chunk T_T/NNP)
#   ,/,
#   or/CC
#   i/VB
#   just/RB
#   worry/VB
#   too/RB
#   much/JJ
#   ,/,
#   (Chunk Juuuuuuuuuuuuuuuuussssst/NNP Chillin/NNP)
#   ,/,
#   (Chunk Sunny/NNP Again/NNP Work/NNP Tomorrow/NNP)
#   -/:
#   TV/NN
#   (Chunk Tonight/NNP)
#   ,/,
#   handed/VBN
#   in/IN
#   my/PRP$
#   uniform/JJ
#   today/NN
#   ./.
#   i/VB
#   miss/VBP
#   you/PRP
#   already/RB
#   ,/,
#   hmmmm/NN
#   .../:
#   ./.
#   i/VB
#   wonder/VBP
#   how/WRB
#   she/PRP
#   my/PRP$
#   number/NN
#   -/:
#   ,/,
#   I/PRP
#   must/MD
#   think/VB
#   about/IN
#   positive../NN
#   ,/,
#   thanks/NNS
#   to/TO
#   all/PDT
#   the/DT
#   haters/NNS
#   up/RP
#   in/IN
#   my/PRP$
#   face/NN
#   all/DT
#   day/NN
#   112-102/CD
#   ,/,
#   this/DT
#   weekend/NN
#   has/VBZ
#   sucked/VBN
#   so/RB
#   far/RB
#   ,/,
#   jb/JJ
#   isnt/NN
#   showing/VBG
#   in/IN
#   australia/JJ
#   any/DT
#   more/JJR
#   ,/,
#   ok/JJ
#   thats/NNS
#   it/PRP
#   you/PRP
#   win./VBP
#   ,/,
#   lt/FW
#   --/:
#   --/:
#   --/:
#   --/:
#   This/DT
#   is/VBZ
#   the/DT
#   way/NN
#   i/JJ
#   feel/VBP
#   right/RB
#   now/RB
#   .../:
#   ,/,
#   awhhe/JJ
#   man/NN
#   .../:
#   ./.
#   I/PRP
#   m/VBP
#   completely/RB
#   useless/JJ
#   rt/NN
#   now/RB
#   ./.
#   Funny/IN
#   all/DT
#   I/PRP
#   can/MD
#   do/VB
#   is/VBZ
#   twitter/NN
#   ./.
#   ,/,
#   Feeling/VBG
#   strangely/RB
#   fine/JJ
#   ./.
#   Now/RB
#   I/PRP
#   m/VBP
#   gon/VBG
#   na/TO
#   go/VB
#   listen/RBR
#   to/TO
#   some/DT
#   (Chunk Semisonic/NNP)
#   to/TO
#   celebrate/VB
#   ,/,
#   (Chunk HUGE/NNP roll/NN)
#   of/IN
#   thunder/NN
#   just/RB
#   now/RB
#   .../:
#   (Chunk SO/NNP)
#   scary/JJ
#   ,/,
#   I/PRP
#   just/RB
#   cut/VB
#   my/PRP$
#   beard/NN
#   off/IN
#   ./.
#   It/PRP
#   s/VBD
#   only/RB
#   been/VBN
#   growing/VBG
#   for/IN
#   well/RB
#   over/IN
#   a/DT
#   year/NN
#   ./.
#   I/PRP
#   m/VBP
#   gon/VBG
#   na/TO
#   start/VB
#   it/PRP
#   over/RP
#   ./.
#   shaunamanu/NN
#   is/VBZ
#   happy/JJ
#   in/IN
#   the/DT
#   meantime./NN
#   ,/,
#   Very/RB
#   sad/JJ
#   about/IN
#   (Chunk Iran./NNP)
#   ,/,
#   wompppp/NN
#   wompp/NN
#   ,/,
#   You/PRP
#   re/VBP
#   the/DT
#   only/JJ
#   one/NN
#   who/WP
#   can/MD
#   see/VB
#   this/DT
#   cause/NN
#   no/DT
#   one/NN
#   else/RB
#   is/VBZ
#   following/VBG
#   me/PRP
#   this/DT
#   is/VBZ
#   for/IN
#   you/PRP
#   because/IN
#   you/PRP
#   re/VBP
#   pretty/RB
#   awesome/JJ
#   ,/,
#   lt/FW
#   --/:
#   -Sad/JJ
#   level/NN
#   is/VBZ
#   3/CD
#   ./.
#   I/PRP
#   was/VBD
#   writing/VBG
#   a/DT
#   massive/JJ
#   blog/NN
#   tweet/NN
#   on/IN
#   (Chunk Myspace/NNP)
#   and/CC
#   my/PRP$
#   comp/NN
#   shut/VBD
#   down/RB
#   ./.
#   Now/RB
#   it/PRP
#   s/VBZ
#   all/DT
#   lost/VBN
#   *lays/NNS
#   in/IN
#   fetal/JJ
#   position*/NN
#   ,/,
#   .../:
#   Headed/VBN
#   to/TO
#   (Chunk Hospitol/NNP Had/NNP)
#   to/TO
#   pull/VB
#   out/IN
#   of/IN
#   the/DT
#   (Chunk Golf/NNP Tourny/NNP)
#   in/IN
#   3rd/CD
#   place/NN
#   I/PRP
#   Think/VBP
#   I/PRP
#   Re-Ripped/JJ
#   something/NN
#   (Chunk Yeah/NNP THAT/NNP)
#   ,/,
#   (Chunk BoRinG/NNP)
#   whats/VBZ
#   wrong/JJ
#   with/IN
#   him/PRP
#   (Chunk Please/NNP)
#   tell/VB
#   me/PRP
#   .../:
#   .../:
#   ../SYM
#   -/:
#   ,/,
#   can/MD
#   t/VB
#   be/VB
#   bothered/VBN
#   ./.
#   i/JJ
#   wish/VBP
#   i/NN
#   could/MD
#   spend/VB
#   the/DT
#   rest/NN
#   of/IN
#   my/PRP$
#   life/NN
#   just/RB
#   sat/VBD
#   here/RB
#   and/CC
#   going/VBG
#   to/TO
#   gigs/VB
#   ./.
#   seriously./NN
#   ,/,
#   Feeeling/VBG
#   like/IN
#   shit/NNS
#   right/RB
#   now/RB
#   ./.
#   I/PRP
#   really/RB
#   want/VBP
#   to/TO
#   sleep/VB
#   but/CC
#   nooo/VBP
#   I/PRP
#   have/VBP
#   3/CD
#   hours/NNS
#   of/IN
#   dancing/VBG
#   and/CC
#   an/DT
#   art/JJ
#   assignment/NN
#   to/TO
#   finish/VB
#   ./.
#   ,/,
#   goodbye/JJ
#   exams/FW
#   (Chunk HELLO/NNP ALCOHOL/NNP TONIGHT/NNP)
#   ,/,
#   I/PRP
#   didn/VBP
#   t/JJ
#   realize/VB
#   it/PRP
#   (Chunk was/VBD THAT/NNP)
#   deep/JJ
#   ./.
#   (Chunk Geez/NNP)
#   give/VBP
#   a/DT
#   girl/NN
#   a/DT
#   warning/NN
#   atleast/NN
#   ,/,
#   I/PRP
#   hate/VBP
#   it/PRP
#   when/WRB
#   any/DT
#   athlete/JJ
#   appears/VBZ
#   to/TO
#   tear/VB
#   an/DT
#   (Chunk ACL/NNP)
#   on/IN
#   live/JJ
#   television./NN
#   ,/,
#   i/JJ
#   miss/VBP
#   you/PRP
#   guys/VBP
#   too/RB
#   i/JJ
#   think/VBP
#   i/JJ
#   m/VBP
#   wearing/VBG
#   skinny/NN
#   jeans/NNS
#   a/DT
#   cute/NN
#   sweater/NN
#   and/CC
#   heels/NNS
#   not/RB
#   really/RB
#   sure/JJ
#   what/WP
#   are/VBP
#   you/PRP
#   doing/VBG
#   today/NN
#   ,/,
#   --/:
#   Meet/VB
#   your/PRP$
#   (Chunk Meat/NNP)
#   ,/,
#   (Chunk My/NNP horsie/NN)
#   is/VBZ
#   moving/VBG
#   on/IN
#   (Chunk Saturday/NNP morning./NNP)
#   ,/,
#   (Chunk No/NNP Sat/NNP)
#   off/IN
#   .../:
#   Need/NN
#   to/TO
#   work/VB
#   6/CD
#   days/NNS
#   a/DT
#   week/NN
#   ,/,
#   (Chunk Really/RB Dont/NNP)
#   Like/IN
#   (Chunk Doing/NNP)
#   my/PRP$
#   (Chunk Room/NNP)
#   Its/PRP$
#   (Chunk So/NNP Boring/NNP Sick/NNP)
#   Of/IN
#   (Chunk
#     Doing/NNP
#     My/NNP
#     Wardrobe/NNP
#     Out/NNP
#     Cant/NNP
#     Waiit/NNP
#     Till/NNP)
#   I/PRP
#   Have/VBP
#   My/VBN
#   Walk/NN
#   In/IN
#   One/CD
#   (Chunk Yay/NNP)
#   ,/,
#   (Chunk SOX/NNP Floyd/NNP)
#   was/VBD
#   great/JJ
#   but/CC
#   relievers/NNS
#   need/VBP
#   a/DT
#   scolding/NN
#   ,/,
#   times/NNS
#   by/IN
#   like/IN
#   a/DT
#   million/CD
#   ,/,
#   uploading/VBG
#   pictures/NNS
#   on/IN
#   friendster/NN
#   ,/,
#   what/WP
#   type/NN
#   of/IN
#   a/DT
#   spaz/NN
#   downloads/VBZ
#   a/DT
#   virus/NN
#   my/PRP$
#   brother/NN
#   that/IN
#   s/NN
#   who/WP
#   (Chunk MSN/NNP)
#   is/VBZ
#   now/RB
#   fucked/VBN
#   forever/RB
#   ,/,
#   amp/JJ
#   amp/NN
#   (Chunk Fightiin/NNP Wiit/NNP)
#   The/DT
#   (Chunk Babes/NNP)
#   .../:
#   ,/,
#   -/:
#   so/RB
#   i/JJ
#   wrote/VBD
#   something/NN
#   last/JJ
#   week/NN
#   ./.
#   and/CC
#   i/JJ
#   got/VBD
#   a/DT
#   call/NN
#   from/IN
#   someone/NN
#   in/IN
#   the/DT
#   new/JJ
#   york/NN
#   office/NN
#   .../:
#   ,/,
#   *enough/IN
#   said*/NN
#   ,/,
#   .../:
#   Do/VBP
#   I/PRP
#   need/VBP
#   to/TO
#   even/RB
#   say/VB
#   it/PRP
#   (Chunk Do/NNP)
#   I/PRP
#   (Chunk Well/NNP)
#   here/RB
#   I/PRP
#   go/VBP
#   anyways/JJ
#   (Chunk CHRIS/NNP CORNELL/NNP IN/NNP CHICAGO/NNP)
#   .../:
#   (Chunk TONIGHT/NNP)
#   ,/,
#   .../:
#   health/NN
#   class/NN
#   what/WP
#   a/DT
#   joke/NN
#   ,/,
#   ginaaa/NN
#   lt/NN
#   3/CD
#   (Chunk GO/NNP TO/NNP THE/NNP SHOW/NNP TONIGHT/NNP)
#   ,/,
#   (Chunk Spiral_galaxy/NNP YMPtweet/NNP)
#   it/PRP
#   really/RB
#   makes/VBZ
#   me/PRP
#   sad/JJ
#   when/WRB
#   i/JJ
#   look/VBP
#   at/IN
#   (Chunk Muslims/NNP reality/NN)
#   now/RB
#   ,/,
#   -/:
#   All/DT
#   (Chunk Time/NNP Low/NNP)
#   shall/MD
#   be/VB
#   my/PRP$
#   motivation/NN
#   for/IN
#   the/DT
#   rest/NN
#   of/IN
#   the/DT
#   week./NN
#   ,/,
#   and/CC
#   the/DT
#   entertainment/NN
#   is/VBZ
#   over/IN
#   someone/NN
#   complained/VBD
#   properly../JJ
#   rupturerapture/NN
#   experimental/NN
#   you/PRP
#   say/VBP
#   he/PRP
#   should/MD
#   experiment/VB
#   with/IN
#   a/DT
#   melody/NN
#   ,/,
#   another/DT
#   year/NN
#   of/IN
#   (Chunk Lakers/NNP ../NNP)
#   That/IN
#   s/VBD
#   neither/DT
#   magic/JJ
#   nor/CC
#   fun/NN
#   .../:
#   ,/,
#   baddest/JJS
#   day/NN
#   eveer/NN
#   ./.
#   ,/,
#   bathroom/NN
#   is/VBZ
#   clean/JJ
#   .../:
#   ../RB
#   now/RB
#   on/IN
#   to/TO
#   more/RBR
#   enjoyable/JJ
#   tasks/NNS
#   .../:
#   .../:
#   ,/,
#   boom/NN
#   boom/NN
#   pow/NN
#   ,/,
#   but/CC
#   i/JJ
#   m/NN
#   proud./NN
#   ,/,
#   congrats/NNS
#   to/TO
#   helio/VB
#   though/IN
#   ,/,
#   (Chunk David/NNP)
#   must/MD
#   be/VB
#   hospitalized/VBN
#   for/IN
#   five/CD
#   days/NNS
#   end/NN
#   of/IN
#   (Chunk July/NNP palatine/NN)
#   tonsils/NNS
#   ./.
#   I/PRP
#   will/MD
#   (Chunk probably/RB never/RB see/VB Katie/NNP)
#   in/IN
#   concert/NN
#   ./.
#   ,/,
#   friends/NNS
#   are/VBP
#   leaving/VBG
#   me/PRP
#   cause/NN
#   of/IN
#   this/DT
#   stupid/JJ
#   love/NN
#   ,/,
#   go/VB
#   give/JJ
#   ur/JJ
#   mom/NN
#   a/DT
#   hug/NN
#   right/RB
#   now/RB
#   ./.
#   ,/,
#   Going/VBG
#   To/TO
#   (Chunk See/VB Harry/NNP Sunday/NNP Happiness/NNP)
#   ,/,
#   (Chunk Hand/NNP)
#   quilting/VBG
#   it/PRP
#   is/VBZ
#   then/RB
#   .../:
#   ,/,
#   hate/VB
#   u/NNS
#   .../:
#   leysh/NN
#   t9ar5/NN
#   .../:
#   ../NN
#   ,/,
#   -/:
#   I/PRP
#   always/RB
#   get/VBP
#   what/WP
#   I/PRP
#   want/VBP
#   ,/,
#   I/PRP
#   bend/VBP
#   backwards/NNS
#   ,/,
#   i/NNS
#   get/VBP
#   off/IN
#   work/NN
#   sooooon/NN
#   i/JJ
#   miss/VBP
#   cody/NN
#   booo/NN
#   ./.
#   haven/VBN
#   t/JJ
#   seen/VBN
#   him/PRP
#   in/IN
#   foreverr/NN
#   ,/,
#   I/PRP
#   hate/VBP
#   allergies/NNS
#   ./.
#   Should/MD
#   I/PRP
#   get/VB
#   my/PRP$
#   hair/NN
#   cut/NN
#   tomorrow/NN
#   I/PRP
#   m/VBP
#   taking/VBG
#   a/DT
#   public/JJ
#   poll/NN
#   .../:
#   ,/,
#   -/:
#   I/PRP
#   love/VBP
#   you/PRP
#   guys/VBP
#   so/RB
#   much/JJ
#   that/IN
#   it/PRP
#   hurts/VBZ
#   ./.
#   ,/,
#   I/PRP
#   (Chunk miss/VBP Earl/NNP)
#   ,/,
#   I/PRP
#   (Chunk miss/VBP New/NNP Jersey/NNP)
#   ,/,
#   I/PRP
#   missed/VBD
#   the/DT
#   first/JJ
#   hour/NN
#   of/IN
#   (Chunk SYTYCD/NNP)
#   last/JJ
#   night/NN
#   and/CC
#   I/PRP
#   can/MD
#   t/VB
#   find/VB
#   it/PRP
#   online/PRP
#   ,/,
#   I/PRP
#   need/VBP
#   a/DT
#   (Chunk U2/NNP fix/NN)
#   (Chunk NOW/NNP)
#   ,/,
#   I/PRP
#   never/RB
#   thought/VBD
#   I/PRP
#   d/VBP
#   become/JJ
#   second/JJ
#   choice/NN
#   .../:
#   ,/,
#   I/PRP
#   think/VBP
#   I/PRP
#   may/MD
#   be/VB
#   too/RB
#   friendly/JJ
#   .../:
#   lol/NN
#   .../:
#   o/RB
#   well/RB
#   .../:
#   ,/,
#   I/PRP
#   (Chunk think/VBP Manuel/NNP)
#   my/PRP$
#   (Chunk Basil/NNP plant/NN)
#   only/RB
#   has/VBZ
#   days/NNS
#   to/TO
#   live/VB
#   ,/,
#   I/PRP
#   wan/VBP
#   na/RB
#   be/VB
#   at/IN
#   home/NN
#   church/NN
#   .../:
#   I/PRP
#   wonder/VBP
#   wht/IN
#   they/PRP
#   are/VBP
#   doing/VBG
#   ,/,
#   i/JJ
#   wan/VBP
#   na/RB
#   make/VB
#   my/PRP$
#   own/JJ
#   pizza/NN
#   ,/,
#   i/NN
#   want/VBP
#   a/DT
#   120gb/CD
#   harddrive/NN
#   or/CC
#   a/DT
#   37/CD
#   inch/JJ
#   tv/NN
#   or/CC
#   a/DT
#   new/JJ
#   guitar/NN
#   ./.
#   anyonefeeling/VBG
#   generous/JJ
#   p/NN
#   x/NN
#   ,/,
#   i/JJ
#   want/VBP
#   a/DT
#   hug/NN
#   ,/,
#   I/PRP
#   (Chunk want/VBP Miley/NNP)
#   to/TO
#   (Chunk tour/VB Australia/NNP)
#   ,/,
#   I/PRP
#   wanted/VBD
#   to/TO
#   sleep/VB
#   in/IN
#   this/DT
#   morning/NN
#   but/CC
#   a/DT
#   mean/JJ
#   kid/NN
#   through/IN
#   a/DT
#   popsicle/NN
#   stick/NN
#   at/IN
#   me/PRP
#   head/VBP
#   ./.
#   I/PRP
#   wish/VBP
#   I/PRP
#   could/MD
#   fly/VB
#   away/RB
#   like/IN
#   those/DT
#   squirrels/NNS
#   ,/,
#   i/NN
#   was/VBD
#   too/RB
#   slow/JJ
#   to/TO
#   get/VB
#   1/CD
#   (Chunk Up/NNP tix/NN)
#   ,/,
#   I/PRP
#   will/MD
#   send/VB
#   sunshine/NN
#   to/TO
#   (Chunk Northern/NNP Ireland/NNP)
#   are/VBP
#   you/PRP
#   going/VBG
#   swimming/VBG
#   today/NN
#   kezbat/NN
#   ,/,
#   I/PRP
#   wish/VBP
#   I/PRP
#   could/MD
#   go/VB
#   to/TO
#   (Chunk T4/NNP)
#   On/IN
#   The/DT
#   (Chunk Beach/NNP)
#   Would/MD
#   be/VB
#   great/JJ
#   to/TO
#   (Chunk see/VB Shontelle_Layne/NNP)
#   (Chunk amp/VB DanMerriweather/NNP)
#   ,/,
#   i/NN
#   would/MD
#   be/VB
#   so/RB
#   much/JJ
#   happier/JJR
#   if/IN
#   the/DT
#   walls/NNS
#   of/IN
#   my/PRP$
#   bedroom/NN
#   were/VBD
#   painted/VBN
#   white/JJ
#   ,/,
#   idk/JJ
#   wat/NN
#   2/CD
#   do/NN
#   who/WP
#   can/MD
#   i/VB
#   trust/VB
#   me/PRP
#   im/JJ
#   sorry/JJ
#   4/CD
#   all/DT
#   da/NN
#   pain/NN
#   i/NN
#   have/VBP
#   caused/VBN
#   nebody/JJ
#   ima/JJ
#   take/VB
#   dis/NN
#   time/NN
#   out/IN
#   2/CD
#   straighten/NNS
#   myself/PRP
#   out/RP
#   i/JJ
#   luv/NN
#   yall/NN
#   ,/,
#   I/PRP
#   m/VBP
#   finding/VBG
#   the/DT
#   intercept/NN
#   slope..and/NN
#   banging/VBG
#   my/PRP$
#   head/NN
#   against/IN
#   the/DT
#   wall..Math/NN
#   brain/NN
#   heads/NNS
#   come/VBP
#   save/VB
#   me/PRP
#   ,/,
#   I/PRP
#   m/VBP
#   really/RB
#   going/VBG
#   to/TO
#   bed/VB
#   now/RB
#   .../:
#   ,/,
#   im/VB
#   sick/JJ
#   cough/NN
#   cough/NN
#   ,/,
#   in/IN
#   cab/NN
#   headed/VBN
#   to/TO
#   the/DT
#   airport/NN
#   going/VBG
#   home/NN
#   .../:
#   ./.
#   lt/VB
#   christy/JJ
#   gt/NN
#   ,/,
#   In/IN
#   case/NN
#   I/PRP
#   feel/VBP
#   emo/RB
#   in/IN
#   camp/NN
#   feeling/VBG
#   a/DT
#   wee/JJ
#   bit/NN
#   of/IN
#   it/PRP
#   alr/VBZ
#   .../:
#   am/VBP
#   bringing/VBG
#   in/IN
#   the/DT
#   (Chunk Human/NNP Rights/NNP Watch/NNP World/NNP Report/NNP)
#   2009..hope/CD
#   it/PRP
#   ll/JJ
#   work/NN
#   ,/,
#   (Chunk Jin/NNP)
#   has/VBZ
#   a/DT
#   twitter./NN
#   ,/,
#   jonas/JJ
#   day/NN
#   is/VBZ
#   almost/RB
#   over/IN
#   .../:
#   ,/,
#   (Chunk Jus/NNP Got/NNP Hom/NNP Fr/NNP)
#   ./.
#   (Chunk TDa/NNP Funeral/NNP)
#   .../:
#   I/PRP
#   m/VBP
#   So/RB
#   Sad/JJ
#   I/PRP
#   Cried/VBD
#   So/RB
#   Much/JJ
#   Times/NNS
#   Much/JJ
#   (Chunk Love/NNP Grandpa/NNP)
#   lt/VBD
#   3/CD
#   I/PRP
#   Never/RB
#   Got/VBD
#   To/TO
#   (Chunk Say/VB My/NNP)
#   Last/JJ
#   quot/JJ
#   (Chunk Goodbye/NNP quot/NN)
#   to/TO
#   (Chunk Him./NNP)
#   ,/,
#   just/RB
#   gon/VB
#   na/TO
#   smile/VB
#   .../:
#   cuz/NN
#   it/PRP
#   is/VBZ
#   what/WP
#   it/PRP
#   is..and/VBP
#   im/VBZ
#   not/RB
#   sure/JJ
#   what/WP
#   more/RBR
#   they/PRP
#   could/MD
#   want../VB
#   ,/,
#   (Chunk Just/NNP)
#   got/VBD
#   home/RB
#   and/CC
#   I/PRP
#   got/VBD
#   to/TO
#   see/VB
#   my/PRP$
#   friend/NN
#   (Chunk Zahra/NNP)
#   whom/WP
#   I/PRP
#   haven/VBP
#   t/RB
#   seen/VBN
#   since/IN
#   We/PRP
#   graduated/VBD
#   That/IN
#   makes/VBZ
#   me/PRP
#   so/IN
#   happy./NN
#   ,/,
#   -/:
#   Longest/JJS
#   night/NN
#   ever../NN
#   ugh/IN
#   ,/,
#   mi/FW
#   momacita/FW
#   won/VBD
#   t/JJ
#   let/VB
#   me/PRP
#   go/VB
#   to/TO
#   my/PRP$
#   bf/NN
#   s/RB
#   bball/JJ
#   game/NN
#   grrr/NN
#   ,/,
#   (Chunk Mom/NNP)
#   says/VBZ
#   I/PRP
#   have/VBP
#   to/TO
#   get/VB
#   a/DT
#   new/JJ
#   phone/NN
#   (Chunk IMMEDIATELY/NNP)
#   .../:
#   .off/NN
#   to/TO
#   (Chunk T-Mobile/NNP)
#   ./.
#   she/PRP
#   paying/VBG
#   .../:
#   ./.
#   ,/,
#   My/PRP$
#   new/JJ
#   car/NN
#   was/VBD
#   stolen/VBN
#   .../:
#   .by/JJ
#   my/PRP$
#   mother/NN
#   who/WP
#   wanted/VBD
#   to/TO
#   go/VB
#   pose/RB
#   at/IN
#   church./NN
#   ,/,
#   no/DT
#   hang/NN
#   out/IN
#   with/IN
#   the/DT
#   girls/NNS
#   2day/CD
#   ./.
#   2moro/CD
#   hope/NN
#   so/RB
#   .../:
#   .../:
#   ,/,
#   no/DT
#   movie/NN
#   times/NNS
#   for/IN
#   sunday/JJ
#   Rats/NNPS
#   will/MD
#   have/VB
#   to/TO
#   plan/VB
#   tomorrow/NN
#   ./.
#   I/PRP
#   guess/VBP
#   this/DT
#   means/VBZ
#   I/PRP
#   have/VBP
#   to/TO
#   work/VB
#   on/IN
#   those/DT
#   two/CD
#   presentations/NNS
#   I/PRP
#   am/VBP
#   doing/VBG
#   ,/,
#   no/DT
#   pavel/NN
#   tonight/VBD
#   lt/JJ
#   (Chunk Tigersfan/NNP gt/NN)
#   ,/,
#   not/RB
#   a/DT
#   cool/JJ
#   night./NN
#   ,/,
#   oh/UH
#   thank/NN
#   you/PRP
#   ,/,
#   pleased/VBD
#   ,/,
#   probably/RB
#   guna/JJ
#   get/VB
#   off/RP
#   soon/RB
#   since/IN
#   no/DT
#   one/NN
#   is/VBZ
#   talkin/JJ
#   no/RB
#   more/RBR
#   ,/,
#   (Chunk really/RB wanted/VBD Safina/NNP)
#   to/TO
#   pull/VB
#   out/RP
#   a/DT
#   win/NN
#   amp/NN
#   to/TO
#   lose/VB
#   like/IN
#   that/DT
#   .../:
#   ,/,
#   (Chunk RIP/NNP David/NNP Eddings./NNP)
#   ,/,
#   (Chunk Rose/NNP)
#   and/CC
#   ood/NN
#   will/MD
#   be/VB
#   back/RB
#   in/IN
#   the/DT
#   Xmas/NN
#   (Chunk Who/NNP)
#   special/JJ
#   (Chunk YAY/NNP Damn/NNP)
#   that/IN
#   s/VBZ
#   half/PDT
#   a/DT
#   year/NN
#   away./NN
#   ,/,
#   -/:
#   sannesias/NN
#   (Chunk Aww/NNP)
#   no/DT
#   neighbor/NN
#   We/PRP
#   need/VBP
#   to/TO
#   (Chunk watch/VB Mean/NNP Girls/NNP)
#   ,/,
#   so/RB
#   whats/VBZ
#   the/DT
#   status/NN
#   on/IN
#   next/JJ
#   weekend/NN
#   ,/,
#   sorry/JJ
#   gigi4462/VBP
#   The/DT
#   (Chunk Ex/NNP Husband/NNP)
#   has/VBZ
#   overdosed/VBN
#   on/IN
#   his/PRP$
#   daily/JJ
#   dose/NN
#   of/IN
#   haterade/NN
#   ,/,
#   (Chunk Thanks/NNP)
#   for/IN
#   your/PRP$
#   definition/NN
#   of/IN
#   throwbie/NN
#   Editors/NNS
#   reviewed/VBD
#   your/PRP$
#   entry/NN
#   and/CC
#   have/VBP
#   decided/VBN
#   to/TO
#   not/RB
#   publish/VB
#   it./NN
#   ,/,
#   (Chunk Thanks/NNP)
#   I/PRP
#   need/VBP
#   all/PDT
#   the/DT
#   help/NN
#   i/VB
#   can/MD
#   get./VB
#   ,/,
#   -/:
#   that/IN
#   explains/VBZ
#   alot./RB
#   ,/,
#   There/EX
#   s/VBZ
#   going/VBG
#   to/TO
#   be/VB
#   a/DT
#   (Chunk Heathers/NNP sequel/NN)
#   ./.
#   Winona4ever/IN
#   They/PRP
#   better/VBP
#   not/RB
#   fuck/VB
#   it/PRP
#   up./JJ
#   ,/,
#   told/VBD
#   not/RB
#   to/TO
#   drink/VB
#   w/JJ
#   my/PRP$
#   (Chunk Rx/NNP)
#   so/RB
#   just/RB
#   gave/VBD
#   all/PDT
#   the/DT
#   b.b/NN
#   ./.
#   porter/NN
#   amp/NN
#   obs/NN
#   ./.
#   stout/IN
#   that/DT
#   I/PRP
#   brought/VBD
#   home/NN
#   from/IN
#   (Chunk OR/NNP)
#   to/TO
#   my/PRP$
#   neighbors/NNS
#   ./.
#   v/NN
#   v/NN
#   sad./NN
#   ,/,
#   trae/NN
#   is/VBZ
#   so/RB
#   sweet/JJ
#   He/PRP
#   just/RB
#   bought/VBD
#   me/PRP
#   a/DT
#   new/JJ
#   baithing/NN
#   suit/NN
#   (Chunk Wove/NNP)
#   him/PRP
#   ,/,
#   (Chunk True/NNP)
#   highly/RB
#   subjective/NN
#   of/IN
#   me/PRP
#   there/EX
#   ./.
#   (Chunk Tombre/NNP)
#   was/VBD
#   actually/RB
#   my/PRP$
#   favorite/JJ
#   character/NN
#   in/IN
#   the/DT
#   book/NN
#   ./.
#   You/PRP
#   got/VBD
#   me/PRP
#   -/:
#   -/:
#   Rishabh/NN
#   ,/,
#   u/JJ
#   guys/NNS
#   knw/VBP
#   whyy/NN
#   ,/,
#   very/RB
#   much/RB
#   so/RB
#   ,/,
#   waahhh/NN
#   now/RB
#   I/PRP
#   m/VBP
#   getting/VBG
#   sad/NN
#   .../:
#   .miss/JJ
#   hub/NN
#   -/:
#   quot/NN
#   quot/NN
#   quot/NN
#   quot/NN
#   quot/NN
#   quot/NN
#   quot/NN
#   quot/NN
#   ,/,
#   --/:
#   we/PRP
#   were/VBD
#   standing/VBG
#   out/RP
#   in/IN
#   the/DT
#   pouring/NN
#   rain../NN
#   We/PRP
#   were/VBD
#   sitting/VBG
#   on/IN
#   top/NN
#   of/IN
#   the/DT
#   world../NN
#   --/:
#   summer/NN
#   sucks/NNS
#   --/:
#   ,/,
#   (Chunk Went/NNP)
#   to/TO
#   get/VB
#   dog/NN
#   from/IN
#   vets/NNS
#   theyve/RB
#   stitched/VBD
#   her/PRP
#   ear/NN
#   charged/VBD
#   us/PRP
#   for/IN
#   it/PRP
#   but/CC
#   she/PRP
#   still/RB
#   bleeds/VBZ
#   like/IN
#   a/DT
#   waterfall/NN
#   everytime/NN
#   she/PRP
#   moves/VBZ
#   ./.
#   (Chunk D/NNP WHY/NNP)
#   ,/,
#   where/WRB
#   is/VBZ
#   my/PRP$
#   picture/NN
#   i/JJ
#   feel/NN
#   naked/VBD
#   ,/,
#   Why/WRB
#   aren/VBP
#   t/NN
#   there/RB
#   any/DT
#   trains/NNS
#   going/VBG
#   to/TO
#   manchester/VB
#   on/IN
#   a/DT
#   sunday/NN
#   Now/RB
#   I/PRP
#   can/MD
#   t/VB
#   go/VB
#   to/TO
#   the/DT
#   jonasbrothers/NNS
#   concert./VBP
#   ,/,
#   -/:
#   Why/WRB
#   must/MD
#   people/NNS
#   be/VB
#   so/RB
#   picky/JJ
#   ./.
#   I/PRP
#   mean/VBP
#   6/CD
#   hours/NNS
#   work/NN
#   and/CC
#   no/DT
#   dice/NN
#   what/WP
#   s/VBZ
#   up/RP
#   with/IN
#   that/DT
#   ,/,
#   Why/WRB
#   (Chunk Twitter/NNP)
#   will/MD
#   soon/RB
#   become/VB
#   obsolete/JJ
#   ,/,
#   wide/JJ
#   awake/NN
#   (Chunk NOT/NNP)
#   ,/,
#   yeah/VB
#   me/PRP
#   too/RB
#   ./.
#   Its/PRP$
#   been/VBN
#   awful/JJ
#   weather/NN
#   here/RB
#   for/IN
#   the/DT
#   last/JJ
#   week/NN
#   so/RB
#   that/IN
#   stinks/NNS
#   ./.
#   (Chunk Kristis/NNP)
#   comin/VBD
#   down/RB
#   and/CC
#   moe/NN
#   said/VBD
#   mmmaybe/RB
#   he/PRP
#   take/VB
#   us/PRP
#   for/IN
#   .../:
#   ,/,
#   -/:
#   You/PRP
#   hi/VBP
#   Stranger/JJR
#   (Chunk HELLO/NNP)
#   I/PRP
#   (Chunk AM/VBP FRANK/NNP LAMPARD/NNP HOW/NNP ARE/NNP YOU/NNP)
#   You/PRP
#   fine/VBP
#   You/PRP
#   and/CC
#   urself/JJ
#   (Chunk Stranger/NNP i/NN)
#   am/VBP
#   gay/RB
#   Your/PRP$
#   .../:
#   ,/,
#   you/PRP
#   ll/VBP
#   always/RB
#   be/VB
#   my/PRP$
#   one/CD
#   and/CC
#   only/RB
#   .../:
#   12*23*2007/CD
#   ,/,
#   3turnoffwords/CD
#   this/DT
#   shit/NN
#   sucks/VBZ
#   ,/,
#   asylm/JJ
#   (Chunk J2/NNP panel/NN)
#   is/VBZ
#   over/IN
#   ./.
#   Guess/VB
#   it/PRP
#   s/PRP
#   back/RB
#   to/TO
#   normal/JJ
#   life./NN
#   ,/,
#   poemsunder140/NN
#   .../:
#   .started/VBN
#   by/IN
#   shannonelyse1/NN
#   ,/,
#   squarespace/NN
#   brighten/VB
#   my/PRP$
#   bad/JJ
#   day/NN
#   i/VB
#   never/RB
#   win/VBP
#   anything/NN
#   .../:
#   ,/,
#   (Chunk Susan/NNP Boyle/NNP didnt/NN)
#   win/NN
#   mh/NN
#   well/RB
#   diversity/NN
#   was/VBD
#   very/RB
#   good/JJ
#   though/IN
#   (Chunk CONGRATZ/NNP)
#   ,/,
#   twenty20/NN
#   ,/,
#   lt/NN
#   --/:
#   -/:
#   That/DT
#   is/VBZ
#   all/DT
#   and/CC
#   believe/VBP
#   me../NN
#   it/PRP
#   s/VBZ
#   enough/JJ
#   ,/,
#   lt/JJ
#   3/CD
#   goooood/NN
#   timessss/NN
#   ,/,
#   lt/VBZ
#   3/CD
#   (Chunk GrAdUaTE/NNP)
#   09/CD
#   lt/NN
#   3/CD
#   ,/,
#   quot/NN
#   Vandals/NNS
#   paint/VBP
#   swastikas/NN
#   on/IN
#   home/NN
#   of/IN
#   author/NN
#   of/IN
#   gay/NN
#   lesbian/JJ
#   church/NN
#   story/NN
#   (Chunk Naples/NNP Daily/NNP News/NNP quot/NN)
#   ,/,
#   quot/VBP
#   An/DT
#   unknown/JJ
#   error/NN
#   (Chunk occured/VBD -4/NNP quot/NN)
#   ./.
#   uh/JJ
#   oh/UH
#   ./.
#   iPhone/NN
#   (Chunk OS/NNP)
#   3/CD
#   fail/NN
#   so/RB
#   far/RB
#   ,/,
#   quot/JJ
#   experts/NNS
#   homers/NNS
#   predict/VBP
#   Eagles/NNS
#   to/TO
#   go/VB
#   12-4/JJ
#   and/CC
#   Giants/NNPS
#   to/TO
#   go/VB
#   9-7/JJ
#   (Chunk BS/NNP)
#   ,/,
#   quot/NN
#   I/PRP
#   know/VBP
#   you/PRP
#   hungry/VBP
#   so/RB
#   lets/RB
#   go/VB
#   outside/RB
#   on/IN
#   the/DT
#   balcony/NN
#   so/IN
#   you/PRP
#   can/MD
#   eat/VB
#   quot/NN
#   .../:
#   ./.
#   ,/,
#   quot/VBP
#   I/PRP
#   want/VBP
#   you/PRP
#   so/RB
#   bad/JJ
#   it/PRP
#   s/VBD
#   driving/VBG
#   me/PRP
#   mad/JJ
#   quot/NN
#   ,/,
#   quot/VBD
#   The/DT
#   10/CD
#   (Chunk Men/NNP)
#   a/DT
#   (Chunk
#     UK/NNP
#     Female/NNP
#     Internet/NNP
#     Entrepreneur/NNP
#     Should/NNP
#     Know/NNP)
#   when/WRB
#   Starting/VBG
#   and/CC
#   Growing/VBG
#   a/DT
#   (Chunk Business/NNP)
#   The/DT
#   (Chunk Next/NNP Women/NNP quot/NN)
#   .../:
#   ,/,
#   quot/VBZ
#   The/DT
#   truth/NN
#   is/VBZ
#   hiding/VBG
#   in/IN
#   your/PRP$
#   eyes/NNS
#   quot/VBP
#   patita/JJ
#   (Chunk MissMarian/NNP Paramore/NNP Decode/NNP Daninho502/NNP)
#   ,/,
#   (Chunk quot/RB Try/NNP)
#   to/TO
#   turn/VB
#   on/IN
#   my/PRP$
#   tv/NN
#   to/TO
#   get/VB
#   you/PRP
#   out/IN
#   of/IN
#   my/PRP$
#   head/NN
#   ./.
#   I/PRP
#   ve/VBP
#   got/VBD
#   this/DT
#   feeling/NN
#   inside/IN
#   that/DT
#   I/PRP
#   just/RB
#   won/VBD
#   t/JJ
#   admit/NN
#   .../:
#   quot/NN
#   that/WDT
#   is/VBZ
#   literally/RB
#   how/WRB
#   I/PRP
#   feel/VBP
#   ,/,
#   quot/RB
#   well/RB
#   the/DT
#   truth/NN
#   is/VBZ
#   I/PRP
#   miss/VBP
#   you/PRP
#   so/RB
#   quot/JJ
#   -/:
#   Coldplay/NN
#   ,/,
#   tears/VBZ
#   -/:
#   Today/NN
#   is/VBZ
#   the/DT
#   last/JJ
#   day/NN
#   with/IN
#   my/PRP$
#   kids/NNS
#   .../:
#   They/PRP
#   go/VBP
#   on/IN
#   summer/NN
#   break/NN
#   at/IN
#   their/PRP$
#   (Chunk Dads/NNP tomorrow/NN)
#   ./.
#   *sighs*/NN
#   ,/,
#   unsure/JJ
#   annoyed/VBN
#   ,/,
#   via/IN
#   designrelated/VBN
#   are/VBP
#   designed/VBN
#   gallery/JJ
#   exhibition/NN
#   postcards/NNS
#   mailers/NNS
#   going/VBG
#   extinct/JJ
#   via/IN
#   (Chunk NYT/NNP)
#   ,/,
#   (Chunk *BeautifulyLost/NNP)
#   ,/,
#   -/:
#   *cries*/NN
#   I/PRP
#   m/VBP
#   going/VBG
#   to/TO
#   (Chunk miss/VB Harry/NNP Potter/NNP)
#   when/WRB
#   it/PRP
#   comes/VBZ
#   out/RP
#   ./.
#   I/PRP
#   m/VBP
#   leaving/VBG
#   to/TO
#   (Chunk Vietnam/NNP)
#   on/IN
#   (Chunk July/NNP)
#   11th/CD
#   ./.
#   I/PRP
#   m/VBP
#   going/VBG
#   to/TO
#   cry/VB
#   ,/,
#   --/:
#   *hummin*/NN
#   I/PRP
#   SAY/VBP
#   quot/RB
#   shut/VBN
#   up/RP
#   amp/JJ
#   put/VB
#   your/PRP$
#   money/NN
#   where/WRB
#   your/PRP$
#   mouth/NN
#   is/VBZ
#   quot/JJ
#   .../:
#   headin/VBZ
#   out/RP
#   to/TO
#   reality/NN
#   ./.
#   Cheers/NNS
#   (Chunk Twitter/NNP world/NN)
#   ,/,
#   --/:
#   ./.
#   *sigh*/IN
#   You/PRP
#   cant/VBP
#   love/VB
#   someone/NN
#   that/WDT
#   doesn/VBZ
#   t/RP
#   love/VB
#   you/PRP
#   back/RP
#   that/IN
#   s/NN
#   like/IN
#   stalker/NN
#   status/NN
#   ./.
#   GET/VB
#   a/DT
#   divorce/NN
#   amp/NN
#   amp/JJ
#   move/NN
#   on/IN
#   ./.
#   (Chunk Trinity/NNP)
#   ./.
#   ,/,
#   ./.
#   ./.
#   ./.
#   ./.
#   going/VBG
#   back/RB
#   to/TO
#   bed/NN
#   because/IN
#   I/PRP
#   m/VBP
#   lookin/JJ
#   around/IN
#   and/CC
#   don/VB
#   t/NN
#   see/VB
#   a/DT
#   reason/NN
#   to/TO
#   be/VB
#   awake/JJ
#   atm/NN
#   ./.
#   Be/VB
#   up/RP
#   in/IN
#   a/DT
#   little./NN
#   ,/,
#   --/:
#   ./.
#   (Chunk Aiqht/NNP Goodniqht/NNP)
#   ./.
#   (Chunk Tri/NNP Neena/NNP Malcolm/NNP Chaise/NNP JLew/NNP ATL/NNP)
#   lt/VBZ
#   333/CD
#   (Chunk Love/NNP Much/NNP)
#   ./.
#   ,/,
#   --/:
#   ./.
#   (Chunk Triiiiiii/NNP)
#   ./.
#   ily/RB
#   ./.
#   even/RB
#   if/IN
#   (Chunk Chaise/NNP doesn/NN)
#   t/NN
#   ./.
#   (Chunk D/NNP)
#   *dies/NNS
#   of/IN
#   laughter*/NN
#   ,/,
#   ../VBP
#   i/JJ
#   wantt/VBP
#   hiim/JJ
#   soo/NN
#   badd/NN
#   ,/,
#   ../JJ
#   watching/VBG
#   tv/NN
#   bed/VBD
#   shopping/VBG
#   w./NN
#   mom/NN
#   out/IN
#   w./JJ
#   trent/JJ
#   hopefully/RB
#   i/VBP
#   need/VBP
#   my/PRP$
#   best/JJS
#   friend/NN
#   ,/,
#   .../:
#   had/VBD
#   weird/JJ
#   encounters/NNS
#   with/IN
#   so/RB
#   many/JJ
#   homeless/JJ
#   creeps/NNS
#   on/IN
#   the/DT
#   walk/NN
#   home/NN
#   tonight/NN
#   all/DT
#   by/IN
#   myself/PRP
#   awesome/VBP
#   .../:
#   really/RB
#   .../:
#   ,/,
#   .../:
#   Rained/VBN
#   out/RP
#   truck/NN
#   race/NN
#   ,/,
#   .../:
#   Why/WRB
#   am/VBP
#   I/PRP
#   feeling/VBG
#   worse/JJR
#   (Chunk F/NNP)
#   ,/,
#   .../:
#   ./.
#   Feeling/VBG
#   pain/NN
#   and/CC
#   happiness/NN
#   at/IN
#   the/DT
#   same/JJ
#   time/NN
#   ./.
#   How/WRB
#   confusing/JJ
#   ,/,
#   .../:
#   ../PRP
#   hot/JJ
#   choco/NN
#   is/VBZ
#   the/DT
#   best/JJS
#   ,/,
#   .../:
#   .in/VBZ
#   a/DT
#   shirt/NN
#   and/CC
#   panties/NNS
#   ./.
#   celulite/NN
#   ,/,
#   ..had/VBD
#   to/TO
#   turn/VB
#   back/RB
#   to/TO
#   (Chunk North/NNP)
#   due/JJ
#   to/TO
#   body/VB
#   on/IN
#   line/NN
#   ./.
#   So/IN
#   (Chunk missing/VBG Design/NNP Council/NNP Design/NNP)
#   4/CD
#   (Chunk Tech/NNP Transfer/NNP event/NN)
#   ,/,
#   (Chunk ..y/NNP everything/NN)
#   is/VBZ
#   so/RB
#   hard/JJ
#   ,/,
#   .bueno/JJ
#   good/JJ
#   bye/NN
#   ./.
#   good/JJ
#   night/NN
#   ,/,
#   (Chunk Beach/NNP day/NN)
#   with/IN
#   (Chunk Scoobs/NNP)
#   ./.
#   Still/RB
#   no/DT
#   phone./NN
#   ,/,
#   (Chunk Let/NNP)
#   s/PRP
#   have/VB
#   fun/VBN
#   ./.
#   When/WRB
#   I/PRP
#   give/VBP
#   ya/PRP
#   what/WP
#   I/PRP
#   give/VBP
#   ya./NN
#   ,/,
#   I/PRP
#   don/VBP
#   t/JJ
#   want/VBP
#   to/TO
#   move/VB
#   ,/,
#   -D/NN
#   .../:
#   WHAT/WP
#   (Chunk AN/NNP)
#   AMAZING/JJ
#   (Chunk NIGHT/NNP DAY/NNP)
#   (Chunk amp/VBD NIGHT/NNP AGAIN/NNP HI/NNP TWITS/NNP)
#   I/PRP
#   (Chunk MiSS/NNP U/NNP GUYS/NNP)
#   ,/,
#   canaveral/JJ
#   national/JJ
#   seashore/NN
#   ,/,
#   progressing/VBG
#   in/IN
#   the/DT
#   production/NN
#   department/NN
#   with/IN
#   quot/PDT
#   The/DT
#   (Chunk Uprizing/NNP quot/NN)
#   thats/VBZ
#   the/DT
#   priority/NN
#   getting/VBG
#   the/DT
#   head/NN
#   nodding/VBG
#   beats/NNS
#   and/CC
#   then/RB
#   we/PRP
#   reach/VBP
#   out/RP
#   ,/,
#   taylorrhicks/NNS
#   enjoy/VBP
#   chicago..b/JJ
#   new/JJ
#   venue/NN
#   is/VBZ
#   always/RB
#   cool/JJ
#   ./.
#   You/PRP
#   shine/VBP
#   everywhere/RB
#   you/PRP
#   go/VBP
#   ./.
#   I/PRP
#   know/VBP
#   who/WP
#   you/PRP
#   are/VBP
#   ./.
#   In/IN
#   time/NN
#   so/RB
#   will/MD
#   everyone/NN
#   ./.
#   ,/,
#   the/DT
#   train/NN
#   crash/NN
#   in/IN
#   (Chunk DC/NNP)
#   .../:
#   ../NN
#   ,/,
#   (Chunk Thestreetforce/NNP)
#   ,/,
#   3sixty5days/CD
#   makes/VBZ
#   me/PRP
#   smile./JJ
#   ,/,
#   adamisacson/JJ
#   (Chunk My/NNP)
#   first/RB
#   day/NN
#   off/IN
#   in/IN
#   3/CD
#   weeks/NNS
#   and/CC
#   my/PRP$
#   child/NN
#   got/VBD
#   up/RB
#   before/RB
#   7/CD
#   00/CD
#   ./.
#   So/RB
#   watch/NN
#   for/IN
#   me/PRP
#   on/IN
#   quot/NN
#   (Chunk Nancy/NNP Grac../NNP)
#   ,/,
#   adbert/JJ
#   quot/NN
#   (Chunk Video/NNP Woody/NNP Woodpecker/NNP)
#   The/DT
#   (Chunk Barber/NNP)
#   of/IN
#   (Chunk Seville/NNP)
#   I/PRP
#   am/VBP
#   great/JJ
#   klitoria/NN
#   just/RB
#   wishing/VBG
#   to/TO
#   be/VB
#   a/DT
#   ch/NN
#   .../:
#   ,/,
#   alexrauchman/JJ
#   I/PRP
#   am/VBP
#   happy/JJ
#   you/PRP
#   are/VBP
#   staying/VBG
#   around/RB
#   here/RB
#   ./.
#   (Chunk Drexel/NNP)
#   is/VBZ
#   a/DT
#   fabulous/JJ
#   university/NN
#   ./.
#   You/PRP
#   should/MD
#   be/VB
#   proud/JJ
#   ./.
#   yeah./NN
#   ,/,
#   alvinkschneider/VB
#   what/WP
#   happened/VBD
#   to/TO
#   angels/NNS
#   and/CC
#   demons/NNS
#   and/CC
#   lions/NNS
#   and/CC
#   tigers/NNS
#   and/CC
#   bears/NNS
#   ,/,
#   (Chunk AmericanWomannn/NNP Well/NNP)
#   that/IN
#   sure/JJ
#   minimizes/VBZ
#   the/DT
#   impact/NN
#   .../:
#   (Chunk LOL/NNP)
#   ,/,
#   ange_black/NN
#   sween/NN
#   I/PRP
#   call/VBP
#   dibs/NNS
#   on/IN
#   the/DT
#   (Chunk Voltron/NNP arm/NN)
#   ./.
#   No/CC
#   the/DT
#   leg/NN
#   ./.
#   (Chunk Wait/NNP)
#   ./.
#   Where/WRB
#   are/VBP
#   my/PRP$
#   manners/NNS
#   baileygenine/VBP
#   ../NN
#   ,/,
#   (Chunk CharlottegC/NNP)
#   I/PRP
#   just/RB
#   saw/VBD
#   ur/JJ
#   mum/NN
#   ,/,
#   chloelunn/NN
#   and/CC
#   (Chunk
#     meganmcdowell/VB
#     GET/NNP
#     YOUR/NNP
#     FAT/NNP
#     ASSES/NNP
#     ON/NNP
#     HERE/NNP)
#   ./.
#   (Chunk NAI./NNP)
#   ,/,
#   -/:
#   codinghorror/NN
#   (Chunk See/NNP)
#   three/CD
#   external/JJ
#   monitors/NNS
#   on/IN
#   one/CD
#   laptop/NN
#   (Chunk Win7RC/NNP)
#   1/CD
#   x/VBD
#   1920x1080/CD
#   2/CD
#   x/NN
#   1280x1024/CD
#   ,/,
#   copicmarker/NN
#   quot/NN
#   facebook.com/NN
#   copic.marker/NN
#   if/IN
#   you/PRP
#   re/VBP
#   cool/JJ
#   ./.
#   Or/CC
#   if/IN
#   you/PRP
#   re/VBP
#   not/RB
#   cool/JJ
#   ./.
#   Maybe/RB
#   I/PRP
#   ll/VBP
#   send/VB
#   some/DT
#   cool/JJ
#   ../NN
#   ,/,
#   crewislife/VBP
#   you/PRP
#   want/VBP
#   to/TO
#   start/VB
#   the/DT
#   morning/NN
#   later/RB
#   in/IN
#   (Chunk New/NNP York/NNP)
#   we/PRP
#   can/MD
#   do/VB
#   that/DT
#   Californians/NNPS
#   have/VBP
#   it/PRP
#   even/RB
#   better/RBR
#   ,/,
#   cybervenus/JJ
#   (Chunk LOL/NNP LuV/NNP IT/NNP)
#   gt/VBD
#   gt/NN
#   (Chunk Did/NNP)
#   any1/VB
#   find/NN
#   or/CC
#   c/VB
#   1/CD
#   a../NN
#   ,/,
#   dandelionas/NN
#   is/VBZ
#   making/VBG
#   fettucini/NNS
#   and/CC
#   garlic/JJ
#   bread/NN
#   ,/,
#   danregal/JJ
#   tell/VBP
#   pfont/NN
#   i/NN
#   said/VBD
#   Happy/JJ
#   (Chunk BDay/NNP)
#   ,/,
#   -/:
#   (Chunk Darcy_Lussier/NNP)
#   lkrammes/VBZ
#   I/PRP
#   went/VBD
#   to/TO
#   work/VB
#   once/RB
#   last/JJ
#   year/NN
#   with/IN
#   no/DT
#   pants/NNS
#   ./.
#   Ironically/RB
#   that/DT
#   was/VBD
#   my/PRP$
#   last/JJ
#   day/NN
#   of/IN
#   work/NN
#   at/IN
#   that/DT
#   job/NN
#   ./.
#   (Chunk FML/NNP)
#   ,/,
#   (Chunk DirtyRose17/NNP)
#   told/VBD
#   you/PRP
#   you/PRP
#   would/MD
#   sweep/VB
#   haha/NN
#   (Chunk -p/NNP)
#   ,/,
#   dreamingspires/VBZ
#   ./.
#   there/EX
#   r/VBZ
#   many/JJ
#   gr8/NNS
#   science/NN
#   cartoons/NNS
#   ,/,
#   -/:
#   (Chunk Em91/NNP Edinburgh/NNP fringe/NN)
#   is/VBZ
#   only/RB
#   10/CD
#   weeks/NNS
#   away/RB
#   I/PRP
#   need/VBP
#   monies/NNS
#   (Chunk Btw/NNP)
#   I/PRP
#   m/VBP
#   Elliott/RB
#   from/IN
#   angryfeet/NN
#   -/:
#   blame/NN
#   howlieT/NN
#   for/IN
#   the/DT
#   (Chunk Twitter/NNP intrusion/NN))
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-10-ab63ffaba85a> in <module>()
# ----> 1 chunkingData(taggedData)
#
# <ipython-input-6-286aef567aca> in chunkingData(x)
#      84     chunked = chunkParser.parse(x)
#      85     print (chunked)
# ---> 86     chunked.draw()
#      87
#      88 #Named Entity Recognition of data
#
# /usr/local/lib/python3.6/dist-packages/nltk/tree.py in draw(self)
#     752         from nltk.draw.tree import draw_trees
#     753
# --> 754         draw_trees(self)
#     755
#     756     def pretty_print(self, sentence=None, highlight=(), stream=None, **kwargs):
#
# /usr/local/lib/python3.6/dist-packages/nltk/draw/tree.py in draw_trees(*trees)
#    1006     :rtype: None
#    1007     """
# -> 1008     TreeView(*trees).mainloop()
#    1009     return
#    1010
#
# /usr/local/lib/python3.6/dist-packages/nltk/draw/tree.py in __init__(self, *trees)
#     857         self._trees = trees
#     858
# --> 859         self._top = Tk()
#     860         self._top.title('NLTK')
#     861         self._top.bind('<Control-x>', self.destroy)
#
# /usr/lib/python3.6/tkinter/__init__.py in __init__(self, screenName, baseName, className, useTk, sync, use)
#    2021                 baseName = baseName + ext
#    2022         interactive = 0
# -> 2023         self.tk = _tkinter.create(screenName, baseName, className, interactive, wantobjects, useTk, sync, use)
#    2024         if useTk:
#    2025             self._loadtk()
#
# TclError: no display name and no $DISPLAY environment variable

# %%
nerData(taggedData)
# Out:
# (S
#   is/VBZ
#   so/RB
#   sad/JJ
#   for/IN
#   my/PRP$
#   APL/NNP
#   friend/NN
#   .../:
#   .../:
#   .../:
#   .../:
#   ./.
#   ,/,
#   I/PRP
#   missed/VBD
#   the/DT
#   (NE New/NNP Moon/NNP)
#   trailer/NN
#   .../:
#   ,/,
#   omg/VB
#   its/PRP$
#   already/RB
#   7/CD
#   30/CD
#   O/NNP
#   ,/,
#   ../NNP
#   Omgaga/NNP
#   ./.
#   Im/NNP
#   sooo/VBD
#   im/JJ
#   gunna/NN
#   CRy/NNP
#   ./.
#   I/PRP
#   ve/VBP
#   been/VBN
#   at/IN
#   this/DT
#   dentist/NN
#   since/IN
#   11../CD
#   I/PRP
#   was/VBD
#   suposed/VBN
#   2/CD
#   just/RB
#   get/VB
#   a/DT
#   crown/NN
#   put/VBD
#   on/IN
#   30mins/CD
#   .../:
#   ,/,
#   i/JJ
#   think/VBP
#   mi/JJ
#   bf/NN
#   is/VBZ
#   cheating/VBG
#   on/IN
#   me/PRP
#   T_T/NNP
#   ,/,
#   or/CC
#   i/VB
#   just/RB
#   worry/VB
#   too/RB
#   much/JJ
#   ,/,
#   (NE Juuuuuuuuuuuuuuuuussssst/NNP Chillin/NNP)
#   ,/,
#   (NE Sunny/NNP Again/NNP Work/NNP Tomorrow/NNP)
#   -/:
#   TV/NN
#   Tonight/NNP
#   ,/,
#   handed/VBN
#   in/IN
#   my/PRP$
#   uniform/JJ
#   today/NN
#   ./.
#   i/VB
#   miss/VBP
#   you/PRP
#   already/RB
#   ,/,
#   hmmmm/NN
#   .../:
#   ./.
#   i/VB
#   wonder/VBP
#   how/WRB
#   she/PRP
#   my/PRP$
#   number/NN
#   -/:
#   ,/,
#   I/PRP
#   must/MD
#   think/VB
#   about/IN
#   positive../NN
#   ,/,
#   thanks/NNS
#   to/TO
#   all/PDT
#   the/DT
#   haters/NNS
#   up/RP
#   in/IN
#   my/PRP$
#   face/NN
#   all/DT
#   day/NN
#   112-102/CD
#   ,/,
#   this/DT
#   weekend/NN
#   has/VBZ
#   sucked/VBN
#   so/RB
#   far/RB
#   ,/,
#   jb/JJ
#   isnt/NN
#   showing/VBG
#   in/IN
#   australia/JJ
#   any/DT
#   more/JJR
#   ,/,
#   ok/JJ
#   thats/NNS
#   it/PRP
#   you/PRP
#   win./VBP
#   ,/,
#   lt/FW
#   --/:
#   --/:
#   --/:
#   --/:
#   This/DT
#   is/VBZ
#   the/DT
#   way/NN
#   i/JJ
#   feel/VBP
#   right/RB
#   now/RB
#   .../:
#   ,/,
#   awhhe/JJ
#   man/NN
#   .../:
#   ./.
#   I/PRP
#   m/VBP
#   completely/RB
#   useless/JJ
#   rt/NN
#   now/RB
#   ./.
#   Funny/IN
#   all/DT
#   I/PRP
#   can/MD
#   do/VB
#   is/VBZ
#   twitter/NN
#   ./.
#   ,/,
#   Feeling/VBG
#   strangely/RB
#   fine/JJ
#   ./.
#   Now/RB
#   I/PRP
#   m/VBP
#   gon/VBG
#   na/TO
#   go/VB
#   listen/RBR
#   to/TO
#   some/DT
#   Semisonic/NNP
#   to/TO
#   celebrate/VB
#   ,/,
#   (NE HUGE/NNP)
#   roll/NN
#   of/IN
#   thunder/NN
#   just/RB
#   now/RB
#   .../:
#   SO/NNP
#   scary/JJ
#   ,/,
#   I/PRP
#   just/RB
#   cut/VB
#   my/PRP$
#   beard/NN
#   off/IN
#   ./.
#   It/PRP
#   s/VBD
#   only/RB
#   been/VBN
#   growing/VBG
#   for/IN
#   well/RB
#   over/IN
#   a/DT
#   year/NN
#   ./.
#   I/PRP
#   m/VBP
#   gon/VBG
#   na/TO
#   start/VB
#   it/PRP
#   over/RP
#   ./.
#   shaunamanu/NN
#   is/VBZ
#   happy/JJ
#   in/IN
#   the/DT
#   meantime./NN
#   ,/,
#   Very/RB
#   sad/JJ
#   about/IN
#   Iran./NNP
#   ,/,
#   wompppp/NN
#   wompp/NN
#   ,/,
#   You/PRP
#   re/VBP
#   the/DT
#   only/JJ
#   one/NN
#   who/WP
#   can/MD
#   see/VB
#   this/DT
#   cause/NN
#   no/DT
#   one/NN
#   else/RB
#   is/VBZ
#   following/VBG
#   me/PRP
#   this/DT
#   is/VBZ
#   for/IN
#   you/PRP
#   because/IN
#   you/PRP
#   re/VBP
#   pretty/RB
#   awesome/JJ
#   ,/,
#   lt/FW
#   --/:
#   -Sad/JJ
#   level/NN
#   is/VBZ
#   3/CD
#   ./.
#   I/PRP
#   was/VBD
#   writing/VBG
#   a/DT
#   massive/JJ
#   blog/NN
#   tweet/NN
#   on/IN
#   (NE Myspace/NNP)
#   and/CC
#   my/PRP$
#   comp/NN
#   shut/VBD
#   down/RB
#   ./.
#   Now/RB
#   it/PRP
#   s/VBZ
#   all/DT
#   lost/VBN
#   *lays/NNS
#   in/IN
#   fetal/JJ
#   position*/NN
#   ,/,
#   .../:
#   Headed/VBN
#   to/TO
#   (NE Hospitol/NNP Had/NNP)
#   to/TO
#   pull/VB
#   out/IN
#   of/IN
#   the/DT
#   (NE Golf/NNP Tourny/NNP)
#   in/IN
#   3rd/CD
#   place/NN
#   I/PRP
#   Think/VBP
#   I/PRP
#   Re-Ripped/JJ
#   something/NN
#   Yeah/NNP
#   THAT/NNP
#   ,/,
#   (NE BoRinG/NNP)
#   whats/VBZ
#   wrong/JJ
#   with/IN
#   him/PRP
#   Please/NNP
#   tell/VB
#   me/PRP
#   .../:
#   .../:
#   ../SYM
#   -/:
#   ,/,
#   can/MD
#   t/VB
#   be/VB
#   bothered/VBN
#   ./.
#   i/JJ
#   wish/VBP
#   i/NN
#   could/MD
#   spend/VB
#   the/DT
#   rest/NN
#   of/IN
#   my/PRP$
#   life/NN
#   just/RB
#   sat/VBD
#   here/RB
#   and/CC
#   going/VBG
#   to/TO
#   gigs/VB
#   ./.
#   seriously./NN
#   ,/,
#   Feeeling/VBG
#   like/IN
#   shit/NNS
#   right/RB
#   now/RB
#   ./.
#   I/PRP
#   really/RB
#   want/VBP
#   to/TO
#   sleep/VB
#   but/CC
#   nooo/VBP
#   I/PRP
#   have/VBP
#   3/CD
#   hours/NNS
#   of/IN
#   dancing/VBG
#   and/CC
#   an/DT
#   art/JJ
#   assignment/NN
#   to/TO
#   finish/VB
#   ./.
#   ,/,
#   goodbye/JJ
#   exams/FW
#   (NE HELLO/NNP)
#   (NE ALCOHOL/NNP TONIGHT/NNP)
#   ,/,
#   I/PRP
#   didn/VBP
#   t/JJ
#   realize/VB
#   it/PRP
#   was/VBD
#   THAT/NNP
#   deep/JJ
#   ./.
#   Geez/NNP
#   give/VBP
#   a/DT
#   girl/NN
#   a/DT
#   warning/NN
#   atleast/NN
#   ,/,
#   I/PRP
#   hate/VBP
#   it/PRP
#   when/WRB
#   any/DT
#   athlete/JJ
#   appears/VBZ
#   to/TO
#   tear/VB
#   an/DT
#   ACL/NNP
#   on/IN
#   live/JJ
#   television./NN
#   ,/,
#   i/JJ
#   miss/VBP
#   you/PRP
#   guys/VBP
#   too/RB
#   i/JJ
#   think/VBP
#   i/JJ
#   m/VBP
#   wearing/VBG
#   skinny/NN
#   jeans/NNS
#   a/DT
#   cute/NN
#   sweater/NN
#   and/CC
#   heels/NNS
#   not/RB
#   really/RB
#   sure/JJ
#   what/WP
#   are/VBP
#   you/PRP
#   doing/VBG
#   today/NN
#   ,/,
#   --/:
#   Meet/VB
#   your/PRP$
#   Meat/NNP
#   ,/,
#   My/NNP
#   horsie/NN
#   is/VBZ
#   moving/VBG
#   on/IN
#   Saturday/NNP
#   morning./NNP
#   ,/,
#   (NE No/NNP Sat/NNP)
#   off/IN
#   .../:
#   Need/NN
#   to/TO
#   work/VB
#   6/CD
#   days/NNS
#   a/DT
#   week/NN
#   ,/,
#   Really/RB
#   Dont/NNP
#   Like/IN
#   Doing/NNP
#   my/PRP$
#   Room/NNP
#   Its/PRP$
#   So/NNP
#   Boring/NNP
#   Sick/NNP
#   Of/IN
#   Doing/NNP
#   My/NNP
#   Wardrobe/NNP
#   Out/NNP
#   Cant/NNP
#   Waiit/NNP
#   Till/NNP
#   I/PRP
#   Have/VBP
#   My/VBN
#   Walk/NN
#   In/IN
#   One/CD
#   Yay/NNP
#   ,/,
#   (NE SOX/NNP Floyd/NNP)
#   was/VBD
#   great/JJ
#   but/CC
#   relievers/NNS
#   need/VBP
#   a/DT
#   scolding/NN
#   ,/,
#   times/NNS
#   by/IN
#   like/IN
#   a/DT
#   million/CD
#   ,/,
#   uploading/VBG
#   pictures/NNS
#   on/IN
#   friendster/NN
#   ,/,
#   what/WP
#   type/NN
#   of/IN
#   a/DT
#   spaz/NN
#   downloads/VBZ
#   a/DT
#   virus/NN
#   my/PRP$
#   brother/NN
#   that/IN
#   s/NN
#   who/WP
#   (NE MSN/NNP)
#   is/VBZ
#   now/RB
#   fucked/VBN
#   forever/RB
#   ,/,
#   amp/JJ
#   amp/NN
#   (NE Fightiin/NNP Wiit/NNP The/DT Babes/NNP)
#   .../:
#   ,/,
#   -/:
#   so/RB
#   i/JJ
#   wrote/VBD
#   something/NN
#   last/JJ
#   week/NN
#   ./.
#   and/CC
#   i/JJ
#   got/VBD
#   a/DT
#   call/NN
#   from/IN
#   someone/NN
#   in/IN
#   the/DT
#   new/JJ
#   york/NN
#   office/NN
#   .../:
#   ,/,
#   *enough/IN
#   said*/NN
#   ,/,
#   .../:
#   Do/VBP
#   I/PRP
#   need/VBP
#   to/TO
#   even/RB
#   say/VB
#   it/PRP
#   Do/NNP
#   I/PRP
#   Well/NNP
#   here/RB
#   I/PRP
#   go/VBP
#   anyways/JJ
#   (NE CHRIS/NNP CORNELL/NNP)
#   IN/NNP
#   (NE CHICAGO/NNP)
#   .../:
#   (NE TONIGHT/NNP)
#   ,/,
#   .../:
#   health/NN
#   class/NN
#   what/WP
#   a/DT
#   joke/NN
#   ,/,
#   ginaaa/NN
#   lt/NN
#   3/CD
#   GO/NNP
#   TO/NNP
#   THE/NNP
#   (NE SHOW/NNP TONIGHT/NNP)
#   ,/,
#   (NE Spiral_galaxy/NNP)
#   YMPtweet/NNP
#   it/PRP
#   really/RB
#   makes/VBZ
#   me/PRP
#   sad/JJ
#   when/WRB
#   i/JJ
#   look/VBP
#   at/IN
#   (NE Muslims/NNP)
#   reality/NN
#   now/RB
#   ,/,
#   -/:
#   All/DT
#   Time/NNP
#   Low/NNP
#   shall/MD
#   be/VB
#   my/PRP$
#   motivation/NN
#   for/IN
#   the/DT
#   rest/NN
#   of/IN
#   the/DT
#   week./NN
#   ,/,
#   and/CC
#   the/DT
#   entertainment/NN
#   is/VBZ
#   over/IN
#   someone/NN
#   complained/VBD
#   properly../JJ
#   rupturerapture/NN
#   experimental/NN
#   you/PRP
#   say/VBP
#   he/PRP
#   should/MD
#   experiment/VB
#   with/IN
#   a/DT
#   melody/NN
#   ,/,
#   another/DT
#   year/NN
#   of/IN
#   (NE Lakers/NNP)
#   ../NNP
#   That/IN
#   s/VBD
#   neither/DT
#   magic/JJ
#   nor/CC
#   fun/NN
#   .../:
#   ,/,
#   baddest/JJS
#   day/NN
#   eveer/NN
#   ./.
#   ,/,
#   bathroom/NN
#   is/VBZ
#   clean/JJ
#   .../:
#   ../RB
#   now/RB
#   on/IN
#   to/TO
#   more/RBR
#   enjoyable/JJ
#   tasks/NNS
#   .../:
#   .../:
#   ,/,
#   boom/NN
#   boom/NN
#   pow/NN
#   ,/,
#   but/CC
#   i/JJ
#   m/NN
#   proud./NN
#   ,/,
#   congrats/NNS
#   to/TO
#   helio/VB
#   though/IN
#   ,/,
#   (NE David/NNP)
#   must/MD
#   be/VB
#   hospitalized/VBN
#   for/IN
#   five/CD
#   days/NNS
#   end/NN
#   of/IN
#   July/NNP
#   palatine/NN
#   tonsils/NNS
#   ./.
#   I/PRP
#   will/MD
#   probably/RB
#   never/RB
#   see/VB
#   (NE Katie/NNP)
#   in/IN
#   concert/NN
#   ./.
#   ,/,
#   friends/NNS
#   are/VBP
#   leaving/VBG
#   me/PRP
#   cause/NN
#   of/IN
#   this/DT
#   stupid/JJ
#   love/NN
#   ,/,
#   go/VB
#   give/JJ
#   ur/JJ
#   mom/NN
#   a/DT
#   hug/NN
#   right/RB
#   now/RB
#   ./.
#   ,/,
#   Going/VBG
#   To/TO
#   See/VB
#   (NE Harry/NNP)
#   Sunday/NNP
#   Happiness/NNP
#   ,/,
#   (NE Hand/NNP)
#   quilting/VBG
#   it/PRP
#   is/VBZ
#   then/RB
#   .../:
#   ,/,
#   hate/VB
#   u/NNS
#   .../:
#   leysh/NN
#   t9ar5/NN
#   .../:
#   ../NN
#   ,/,
#   -/:
#   I/PRP
#   always/RB
#   get/VBP
#   what/WP
#   I/PRP
#   want/VBP
#   ,/,
#   I/PRP
#   bend/VBP
#   backwards/NNS
#   ,/,
#   i/NNS
#   get/VBP
#   off/IN
#   work/NN
#   sooooon/NN
#   i/JJ
#   miss/VBP
#   cody/NN
#   booo/NN
#   ./.
#   haven/VBN
#   t/JJ
#   seen/VBN
#   him/PRP
#   in/IN
#   foreverr/NN
#   ,/,
#   I/PRP
#   hate/VBP
#   allergies/NNS
#   ./.
#   Should/MD
#   I/PRP
#   get/VB
#   my/PRP$
#   hair/NN
#   cut/NN
#   tomorrow/NN
#   I/PRP
#   m/VBP
#   taking/VBG
#   a/DT
#   public/JJ
#   poll/NN
#   .../:
#   ,/,
#   -/:
#   I/PRP
#   love/VBP
#   you/PRP
#   guys/VBP
#   so/RB
#   much/JJ
#   that/IN
#   it/PRP
#   hurts/VBZ
#   ./.
#   ,/,
#   I/PRP
#   miss/VBP
#   (NE Earl/NNP)
#   ,/,
#   I/PRP
#   miss/VBP
#   (NE New/NNP Jersey/NNP)
#   ,/,
#   I/PRP
#   missed/VBD
#   the/DT
#   first/JJ
#   hour/NN
#   of/IN
#   (NE SYTYCD/NNP)
#   last/JJ
#   night/NN
#   and/CC
#   I/PRP
#   can/MD
#   t/VB
#   find/VB
#   it/PRP
#   online/PRP
#   ,/,
#   I/PRP
#   need/VBP
#   a/DT
#   U2/NNP
#   fix/NN
#   NOW/NNP
#   ,/,
#   I/PRP
#   never/RB
#   thought/VBD
#   I/PRP
#   d/VBP
#   become/JJ
#   second/JJ
#   choice/NN
#   .../:
#   ,/,
#   I/PRP
#   think/VBP
#   I/PRP
#   may/MD
#   be/VB
#   too/RB
#   friendly/JJ
#   .../:
#   lol/NN
#   .../:
#   o/RB
#   well/RB
#   .../:
#   ,/,
#   I/PRP
#   think/VBP
#   Manuel/NNP
#   my/PRP$
#   Basil/NNP
#   plant/NN
#   only/RB
#   has/VBZ
#   days/NNS
#   to/TO
#   live/VB
#   ,/,
#   I/PRP
#   wan/VBP
#   na/RB
#   be/VB
#   at/IN
#   home/NN
#   church/NN
#   .../:
#   I/PRP
#   wonder/VBP
#   wht/IN
#   they/PRP
#   are/VBP
#   doing/VBG
#   ,/,
#   i/JJ
#   wan/VBP
#   na/RB
#   make/VB
#   my/PRP$
#   own/JJ
#   pizza/NN
#   ,/,
#   i/NN
#   want/VBP
#   a/DT
#   120gb/CD
#   harddrive/NN
#   or/CC
#   a/DT
#   37/CD
#   inch/JJ
#   tv/NN
#   or/CC
#   a/DT
#   new/JJ
#   guitar/NN
#   ./.
#   anyonefeeling/VBG
#   generous/JJ
#   p/NN
#   x/NN
#   ,/,
#   i/JJ
#   want/VBP
#   a/DT
#   hug/NN
#   ,/,
#   I/PRP
#   want/VBP
#   (NE Miley/NNP)
#   to/TO
#   tour/VB
#   (NE Australia/NNP)
#   ,/,
#   I/PRP
#   wanted/VBD
#   to/TO
#   sleep/VB
#   in/IN
#   this/DT
#   morning/NN
#   but/CC
#   a/DT
#   mean/JJ
#   kid/NN
#   through/IN
#   a/DT
#   popsicle/NN
#   stick/NN
#   at/IN
#   me/PRP
#   head/VBP
#   ./.
#   I/PRP
#   wish/VBP
#   I/PRP
#   could/MD
#   fly/VB
#   away/RB
#   like/IN
#   those/DT
#   squirrels/NNS
#   ,/,
#   i/NN
#   was/VBD
#   too/RB
#   slow/JJ
#   to/TO
#   get/VB
#   1/CD
#   Up/NNP
#   tix/NN
#   ,/,
#   I/PRP
#   will/MD
#   send/VB
#   sunshine/NN
#   to/TO
#   (NE Northern/NNP Ireland/NNP)
#   are/VBP
#   you/PRP
#   going/VBG
#   swimming/VBG
#   today/NN
#   kezbat/NN
#   ,/,
#   I/PRP
#   wish/VBP
#   I/PRP
#   could/MD
#   go/VB
#   to/TO
#   T4/NNP
#   On/IN
#   The/DT
#   (NE Beach/NNP)
#   Would/MD
#   be/VB
#   great/JJ
#   to/TO
#   see/VB
#   Shontelle_Layne/NNP
#   amp/VB
#   (NE DanMerriweather/NNP)
#   ,/,
#   i/NN
#   would/MD
#   be/VB
#   so/RB
#   much/JJ
#   happier/JJR
#   if/IN
#   the/DT
#   walls/NNS
#   of/IN
#   my/PRP$
#   bedroom/NN
#   were/VBD
#   painted/VBN
#   white/JJ
#   ,/,
#   idk/JJ
#   wat/NN
#   2/CD
#   do/NN
#   who/WP
#   can/MD
#   i/VB
#   trust/VB
#   me/PRP
#   im/JJ
#   sorry/JJ
#   4/CD
#   all/DT
#   da/NN
#   pain/NN
#   i/NN
#   have/VBP
#   caused/VBN
#   nebody/JJ
#   ima/JJ
#   take/VB
#   dis/NN
#   time/NN
#   out/IN
#   2/CD
#   straighten/NNS
#   myself/PRP
#   out/RP
#   i/JJ
#   luv/NN
#   yall/NN
#   ,/,
#   I/PRP
#   m/VBP
#   finding/VBG
#   the/DT
#   intercept/NN
#   slope..and/NN
#   banging/VBG
#   my/PRP$
#   head/NN
#   against/IN
#   the/DT
#   wall..Math/NN
#   brain/NN
#   heads/NNS
#   come/VBP
#   save/VB
#   me/PRP
#   ,/,
#   I/PRP
#   m/VBP
#   really/RB
#   going/VBG
#   to/TO
#   bed/VB
#   now/RB
#   .../:
#   ,/,
#   im/VB
#   sick/JJ
#   cough/NN
#   cough/NN
#   ,/,
#   in/IN
#   cab/NN
#   headed/VBN
#   to/TO
#   the/DT
#   airport/NN
#   going/VBG
#   home/NN
#   .../:
#   ./.
#   lt/VB
#   christy/JJ
#   gt/NN
#   ,/,
#   In/IN
#   case/NN
#   I/PRP
#   feel/VBP
#   emo/RB
#   in/IN
#   camp/NN
#   feeling/VBG
#   a/DT
#   wee/JJ
#   bit/NN
#   of/IN
#   it/PRP
#   alr/VBZ
#   .../:
#   am/VBP
#   bringing/VBG
#   in/IN
#   the/DT
#   (NE Human/NNP Rights/NNP Watch/NNP)
#   World/NNP
#   Report/NNP
#   2009..hope/CD
#   it/PRP
#   ll/JJ
#   work/NN
#   ,/,
#   (NE Jin/NNP)
#   has/VBZ
#   a/DT
#   twitter./NN
#   ,/,
#   jonas/JJ
#   day/NN
#   is/VBZ
#   almost/RB
#   over/IN
#   .../:
#   ,/,
#   (NE Jus/NNP Got/NNP Hom/NNP Fr/NNP)
#   ./.
#   (NE TDa/NNP Funeral/NNP)
#   .../:
#   I/PRP
#   m/VBP
#   So/RB
#   Sad/JJ
#   I/PRP
#   Cried/VBD
#   So/RB
#   Much/JJ
#   Times/NNS
#   Much/JJ
#   Love/NNP
#   Grandpa/NNP
#   lt/VBD
#   3/CD
#   I/PRP
#   Never/RB
#   Got/VBD
#   To/TO
#   Say/VB
#   My/NNP
#   Last/JJ
#   quot/JJ
#   Goodbye/NNP
#   quot/NN
#   to/TO
#   Him./NNP
#   ,/,
#   just/RB
#   gon/VB
#   na/TO
#   smile/VB
#   .../:
#   cuz/NN
#   it/PRP
#   is/VBZ
#   what/WP
#   it/PRP
#   is..and/VBP
#   im/VBZ
#   not/RB
#   sure/JJ
#   what/WP
#   more/RBR
#   they/PRP
#   could/MD
#   want../VB
#   ,/,
#   (NE Just/NNP)
#   got/VBD
#   home/RB
#   and/CC
#   I/PRP
#   got/VBD
#   to/TO
#   see/VB
#   my/PRP$
#   friend/NN
#   Zahra/NNP
#   whom/WP
#   I/PRP
#   haven/VBP
#   t/RB
#   seen/VBN
#   since/IN
#   We/PRP
#   graduated/VBD
#   That/IN
#   makes/VBZ
#   me/PRP
#   so/IN
#   happy./NN
#   ,/,
#   -/:
#   Longest/JJS
#   night/NN
#   ever../NN
#   ugh/IN
#   ,/,
#   mi/FW
#   momacita/FW
#   won/VBD
#   t/JJ
#   let/VB
#   me/PRP
#   go/VB
#   to/TO
#   my/PRP$
#   bf/NN
#   s/RB
#   bball/JJ
#   game/NN
#   grrr/NN
#   ,/,
#   (NE Mom/NNP)
#   says/VBZ
#   I/PRP
#   have/VBP
#   to/TO
#   get/VB
#   a/DT
#   new/JJ
#   phone/NN
#   (NE IMMEDIATELY/NNP)
#   .../:
#   .off/NN
#   to/TO
#   T-Mobile/NNP
#   ./.
#   she/PRP
#   paying/VBG
#   .../:
#   ./.
#   ,/,
#   My/PRP$
#   new/JJ
#   car/NN
#   was/VBD
#   stolen/VBN
#   .../:
#   .by/JJ
#   my/PRP$
#   mother/NN
#   who/WP
#   wanted/VBD
#   to/TO
#   go/VB
#   pose/RB
#   at/IN
#   church./NN
#   ,/,
#   no/DT
#   hang/NN
#   out/IN
#   with/IN
#   the/DT
#   girls/NNS
#   2day/CD
#   ./.
#   2moro/CD
#   hope/NN
#   so/RB
#   .../:
#   .../:
#   ,/,
#   no/DT
#   movie/NN
#   times/NNS
#   for/IN
#   sunday/JJ
#   Rats/NNPS
#   will/MD
#   have/VB
#   to/TO
#   plan/VB
#   tomorrow/NN
#   ./.
#   I/PRP
#   guess/VBP
#   this/DT
#   means/VBZ
#   I/PRP
#   have/VBP
#   to/TO
#   work/VB
#   on/IN
#   those/DT
#   two/CD
#   presentations/NNS
#   I/PRP
#   am/VBP
#   doing/VBG
#   ,/,
#   no/DT
#   pavel/NN
#   tonight/VBD
#   lt/JJ
#   Tigersfan/NNP
#   gt/NN
#   ,/,
#   not/RB
#   a/DT
#   cool/JJ
#   night./NN
#   ,/,
#   oh/UH
#   thank/NN
#   you/PRP
#   ,/,
#   pleased/VBD
#   ,/,
#   probably/RB
#   guna/JJ
#   get/VB
#   off/RP
#   soon/RB
#   since/IN
#   no/DT
#   one/NN
#   is/VBZ
#   talkin/JJ
#   no/RB
#   more/RBR
#   ,/,
#   really/RB
#   wanted/VBD
#   (NE Safina/NNP)
#   to/TO
#   pull/VB
#   out/RP
#   a/DT
#   win/NN
#   amp/NN
#   to/TO
#   lose/VB
#   like/IN
#   that/DT
#   .../:
#   ,/,
#   (NE RIP/NNP David/NNP)
#   Eddings./NNP
#   ,/,
#   (NE Rose/NNP)
#   and/CC
#   ood/NN
#   will/MD
#   be/VB
#   back/RB
#   in/IN
#   the/DT
#   (NE Xmas/NN Who/NNP)
#   special/JJ
#   (NE YAY/NNP Damn/NNP)
#   that/IN
#   s/VBZ
#   half/PDT
#   a/DT
#   year/NN
#   away./NN
#   ,/,
#   -/:
#   sannesias/NN
#   Aww/NNP
#   no/DT
#   neighbor/NN
#   We/PRP
#   need/VBP
#   to/TO
#   watch/VB
#   (NE Mean/NNP Girls/NNP)
#   ,/,
#   so/RB
#   whats/VBZ
#   the/DT
#   status/NN
#   on/IN
#   next/JJ
#   weekend/NN
#   ,/,
#   sorry/JJ
#   gigi4462/VBP
#   The/DT
#   Ex/NNP
#   (NE Husband/NNP)
#   has/VBZ
#   overdosed/VBN
#   on/IN
#   his/PRP$
#   daily/JJ
#   dose/NN
#   of/IN
#   haterade/NN
#   ,/,
#   (NE Thanks/NNP)
#   for/IN
#   your/PRP$
#   definition/NN
#   of/IN
#   throwbie/NN
#   Editors/NNS
#   reviewed/VBD
#   your/PRP$
#   entry/NN
#   and/CC
#   have/VBP
#   decided/VBN
#   to/TO
#   not/RB
#   publish/VB
#   it./NN
#   ,/,
#   Thanks/NNP
#   I/PRP
#   need/VBP
#   all/PDT
#   the/DT
#   help/NN
#   i/VB
#   can/MD
#   get./VB
#   ,/,
#   -/:
#   that/IN
#   explains/VBZ
#   alot./RB
#   ,/,
#   There/EX
#   s/VBZ
#   going/VBG
#   to/TO
#   be/VB
#   a/DT
#   Heathers/NNP
#   sequel/NN
#   ./.
#   Winona4ever/IN
#   They/PRP
#   better/VBP
#   not/RB
#   fuck/VB
#   it/PRP
#   up./JJ
#   ,/,
#   told/VBD
#   not/RB
#   to/TO
#   drink/VB
#   w/JJ
#   my/PRP$
#   Rx/NNP
#   so/RB
#   just/RB
#   gave/VBD
#   all/PDT
#   the/DT
#   b.b/NN
#   ./.
#   porter/NN
#   amp/NN
#   obs/NN
#   ./.
#   stout/IN
#   that/DT
#   I/PRP
#   brought/VBD
#   home/NN
#   from/IN
#   (NE OR/NNP)
#   to/TO
#   my/PRP$
#   neighbors/NNS
#   ./.
#   v/NN
#   v/NN
#   sad./NN
#   ,/,
#   trae/NN
#   is/VBZ
#   so/RB
#   sweet/JJ
#   He/PRP
#   just/RB
#   bought/VBD
#   me/PRP
#   a/DT
#   new/JJ
#   baithing/NN
#   suit/NN
#   Wove/NNP
#   him/PRP
#   ,/,
#   (NE True/NNP)
#   highly/RB
#   subjective/NN
#   of/IN
#   me/PRP
#   there/EX
#   ./.
#   (NE Tombre/NNP)
#   was/VBD
#   actually/RB
#   my/PRP$
#   favorite/JJ
#   character/NN
#   in/IN
#   the/DT
#   book/NN
#   ./.
#   You/PRP
#   got/VBD
#   me/PRP
#   -/:
#   -/:
#   (NE Rishabh/NN)
#   ,/,
#   u/JJ
#   guys/NNS
#   knw/VBP
#   whyy/NN
#   ,/,
#   very/RB
#   much/RB
#   so/RB
#   ,/,
#   waahhh/NN
#   now/RB
#   I/PRP
#   m/VBP
#   getting/VBG
#   sad/NN
#   .../:
#   .miss/JJ
#   hub/NN
#   -/:
#   quot/NN
#   quot/NN
#   quot/NN
#   quot/NN
#   quot/NN
#   quot/NN
#   quot/NN
#   quot/NN
#   ,/,
#   --/:
#   we/PRP
#   were/VBD
#   standing/VBG
#   out/RP
#   in/IN
#   the/DT
#   pouring/NN
#   rain../NN
#   We/PRP
#   were/VBD
#   sitting/VBG
#   on/IN
#   top/NN
#   of/IN
#   the/DT
#   world../NN
#   --/:
#   summer/NN
#   sucks/NNS
#   --/:
#   ,/,
#   Went/NNP
#   to/TO
#   get/VB
#   dog/NN
#   from/IN
#   vets/NNS
#   theyve/RB
#   stitched/VBD
#   her/PRP
#   ear/NN
#   charged/VBD
#   us/PRP
#   for/IN
#   it/PRP
#   but/CC
#   she/PRP
#   still/RB
#   bleeds/VBZ
#   like/IN
#   a/DT
#   waterfall/NN
#   everytime/NN
#   she/PRP
#   moves/VBZ
#   ./.
#   D/NNP
#   WHY/NNP
#   ,/,
#   where/WRB
#   is/VBZ
#   my/PRP$
#   picture/NN
#   i/JJ
#   feel/NN
#   naked/VBD
#   ,/,
#   Why/WRB
#   aren/VBP
#   t/NN
#   there/RB
#   any/DT
#   trains/NNS
#   going/VBG
#   to/TO
#   manchester/VB
#   on/IN
#   a/DT
#   sunday/NN
#   Now/RB
#   I/PRP
#   can/MD
#   t/VB
#   go/VB
#   to/TO
#   the/DT
#   jonasbrothers/NNS
#   concert./VBP
#   ,/,
#   -/:
#   Why/WRB
#   must/MD
#   people/NNS
#   be/VB
#   so/RB
#   picky/JJ
#   ./.
#   I/PRP
#   mean/VBP
#   6/CD
#   hours/NNS
#   work/NN
#   and/CC
#   no/DT
#   dice/NN
#   what/WP
#   s/VBZ
#   up/RP
#   with/IN
#   that/DT
#   ,/,
#   Why/WRB
#   Twitter/NNP
#   will/MD
#   soon/RB
#   become/VB
#   obsolete/JJ
#   ,/,
#   wide/JJ
#   awake/NN
#   (NE NOT/NNP)
#   ,/,
#   yeah/VB
#   me/PRP
#   too/RB
#   ./.
#   Its/PRP$
#   been/VBN
#   awful/JJ
#   weather/NN
#   here/RB
#   for/IN
#   the/DT
#   last/JJ
#   week/NN
#   so/RB
#   that/IN
#   stinks/NNS
#   ./.
#   (NE Kristis/NNP)
#   comin/VBD
#   down/RB
#   and/CC
#   moe/NN
#   said/VBD
#   mmmaybe/RB
#   he/PRP
#   take/VB
#   us/PRP
#   for/IN
#   .../:
#   ,/,
#   -/:
#   You/PRP
#   hi/VBP
#   Stranger/JJR
#   HELLO/NNP
#   I/PRP
#   AM/VBP
#   (NE FRANK/NNP)
#   (NE LAMPARD/NNP)
#   HOW/NNP
#   ARE/NNP
#   YOU/NNP
#   You/PRP
#   fine/VBP
#   You/PRP
#   and/CC
#   urself/JJ
#   Stranger/NNP
#   i/NN
#   am/VBP
#   gay/RB
#   Your/PRP$
#   .../:
#   ,/,
#   you/PRP
#   ll/VBP
#   always/RB
#   be/VB
#   my/PRP$
#   one/CD
#   and/CC
#   only/RB
#   .../:
#   12*23*2007/CD
#   ,/,
#   3turnoffwords/CD
#   this/DT
#   shit/NN
#   sucks/VBZ
#   ,/,
#   asylm/JJ
#   J2/NNP
#   panel/NN
#   is/VBZ
#   over/IN
#   ./.
#   Guess/VB
#   it/PRP
#   s/PRP
#   back/RB
#   to/TO
#   normal/JJ
#   life./NN
#   ,/,
#   poemsunder140/NN
#   .../:
#   .started/VBN
#   by/IN
#   shannonelyse1/NN
#   ,/,
#   squarespace/NN
#   brighten/VB
#   my/PRP$
#   bad/JJ
#   day/NN
#   i/VB
#   never/RB
#   win/VBP
#   anything/NN
#   .../:
#   ,/,
#   (NE Susan/NNP Boyle/NNP)
#   didnt/NN
#   win/NN
#   mh/NN
#   well/RB
#   diversity/NN
#   was/VBD
#   very/RB
#   good/JJ
#   though/IN
#   (NE CONGRATZ/NNP)
#   ,/,
#   twenty20/NN
#   ,/,
#   lt/NN
#   --/:
#   -/:
#   That/DT
#   is/VBZ
#   all/DT
#   and/CC
#   believe/VBP
#   me../NN
#   it/PRP
#   s/VBZ
#   enough/JJ
#   ,/,
#   lt/JJ
#   3/CD
#   goooood/NN
#   timessss/NN
#   ,/,
#   lt/VBZ
#   3/CD
#   GrAdUaTE/NNP
#   09/CD
#   lt/NN
#   3/CD
#   ,/,
#   quot/NN
#   Vandals/NNS
#   paint/VBP
#   swastikas/NN
#   on/IN
#   home/NN
#   of/IN
#   author/NN
#   of/IN
#   gay/NN
#   lesbian/JJ
#   church/NN
#   story/NN
#   (NE Naples/NNP Daily/NNP News/NNP)
#   quot/NN
#   ,/,
#   quot/VBP
#   An/DT
#   unknown/JJ
#   error/NN
#   occured/VBD
#   -4/NNP
#   quot/NN
#   ./.
#   uh/JJ
#   oh/UH
#   ./.
#   (NE iPhone/NN OS/NNP)
#   3/CD
#   fail/NN
#   so/RB
#   far/RB
#   ,/,
#   quot/JJ
#   experts/NNS
#   homers/NNS
#   predict/VBP
#   Eagles/NNS
#   to/TO
#   go/VB
#   12-4/JJ
#   and/CC
#   (NE Giants/NNPS)
#   to/TO
#   go/VB
#   9-7/JJ
#   BS/NNP
#   ,/,
#   quot/NN
#   I/PRP
#   know/VBP
#   you/PRP
#   hungry/VBP
#   so/RB
#   lets/RB
#   go/VB
#   outside/RB
#   on/IN
#   the/DT
#   balcony/NN
#   so/IN
#   you/PRP
#   can/MD
#   eat/VB
#   quot/NN
#   .../:
#   ./.
#   ,/,
#   quot/VBP
#   I/PRP
#   want/VBP
#   you/PRP
#   so/RB
#   bad/JJ
#   it/PRP
#   s/VBD
#   driving/VBG
#   me/PRP
#   mad/JJ
#   quot/NN
#   ,/,
#   quot/VBD
#   The/DT
#   10/CD
#   Men/NNP
#   a/DT
#   UK/NNP
#   Female/NNP
#   Internet/NNP
#   Entrepreneur/NNP
#   Should/NNP
#   Know/NNP
#   when/WRB
#   Starting/VBG
#   and/CC
#   Growing/VBG
#   a/DT
#   Business/NNP
#   The/DT
#   (NE Next/NNP Women/NNP)
#   quot/NN
#   .../:
#   ,/,
#   quot/VBZ
#   The/DT
#   truth/NN
#   is/VBZ
#   hiding/VBG
#   in/IN
#   your/PRP$
#   eyes/NNS
#   quot/VBP
#   patita/JJ
#   (NE MissMarian/NNP Paramore/NNP Decode/NNP Daninho502/NNP)
#   ,/,
#   quot/RB
#   Try/NNP
#   to/TO
#   turn/VB
#   on/IN
#   my/PRP$
#   tv/NN
#   to/TO
#   get/VB
#   you/PRP
#   out/IN
#   of/IN
#   my/PRP$
#   head/NN
#   ./.
#   I/PRP
#   ve/VBP
#   got/VBD
#   this/DT
#   feeling/NN
#   inside/IN
#   that/DT
#   I/PRP
#   just/RB
#   won/VBD
#   t/JJ
#   admit/NN
#   .../:
#   quot/NN
#   that/WDT
#   is/VBZ
#   literally/RB
#   how/WRB
#   I/PRP
#   feel/VBP
#   ,/,
#   quot/RB
#   well/RB
#   the/DT
#   truth/NN
#   is/VBZ
#   I/PRP
#   miss/VBP
#   you/PRP
#   so/RB
#   quot/JJ
#   -/:
#   (NE Coldplay/NN)
#   ,/,
#   tears/VBZ
#   -/:
#   Today/NN
#   is/VBZ
#   the/DT
#   last/JJ
#   day/NN
#   with/IN
#   my/PRP$
#   kids/NNS
#   .../:
#   They/PRP
#   go/VBP
#   on/IN
#   summer/NN
#   break/NN
#   at/IN
#   their/PRP$
#   Dads/NNP
#   tomorrow/NN
#   ./.
#   *sighs*/NN
#   ,/,
#   unsure/JJ
#   annoyed/VBN
#   ,/,
#   via/IN
#   designrelated/VBN
#   are/VBP
#   designed/VBN
#   gallery/JJ
#   exhibition/NN
#   postcards/NNS
#   mailers/NNS
#   going/VBG
#   extinct/JJ
#   via/IN
#   (NE NYT/NNP)
#   ,/,
#   *BeautifulyLost/NNP
#   ,/,
#   -/:
#   *cries*/NN
#   I/PRP
#   m/VBP
#   going/VBG
#   to/TO
#   miss/VB
#   (NE Harry/NNP Potter/NNP)
#   when/WRB
#   it/PRP
#   comes/VBZ
#   out/RP
#   ./.
#   I/PRP
#   m/VBP
#   leaving/VBG
#   to/TO
#   (NE Vietnam/NNP)
#   on/IN
#   July/NNP
#   11th/CD
#   ./.
#   I/PRP
#   m/VBP
#   going/VBG
#   to/TO
#   cry/VB
#   ,/,
#   --/:
#   *hummin*/NN
#   I/PRP
#   SAY/VBP
#   quot/RB
#   shut/VBN
#   up/RP
#   amp/JJ
#   put/VB
#   your/PRP$
#   money/NN
#   where/WRB
#   your/PRP$
#   mouth/NN
#   is/VBZ
#   quot/JJ
#   .../:
#   headin/VBZ
#   out/RP
#   to/TO
#   reality/NN
#   ./.
#   Cheers/NNS
#   Twitter/NNP
#   world/NN
#   ,/,
#   --/:
#   ./.
#   *sigh*/IN
#   You/PRP
#   cant/VBP
#   love/VB
#   someone/NN
#   that/WDT
#   doesn/VBZ
#   t/RP
#   love/VB
#   you/PRP
#   back/RP
#   that/IN
#   s/NN
#   like/IN
#   stalker/NN
#   status/NN
#   ./.
#   GET/VB
#   a/DT
#   divorce/NN
#   amp/NN
#   amp/JJ
#   move/NN
#   on/IN
#   ./.
#   Trinity/NNP
#   ./.
#   ,/,
#   ./.
#   ./.
#   ./.
#   ./.
#   going/VBG
#   back/RB
#   to/TO
#   bed/NN
#   because/IN
#   I/PRP
#   m/VBP
#   lookin/JJ
#   around/IN
#   and/CC
#   don/VB
#   t/NN
#   see/VB
#   a/DT
#   reason/NN
#   to/TO
#   be/VB
#   awake/JJ
#   atm/NN
#   ./.
#   Be/VB
#   up/RP
#   in/IN
#   a/DT
#   little./NN
#   ,/,
#   --/:
#   ./.
#   (NE Aiqht/NNP Goodniqht/NNP)
#   ./.
#   Tri/NNP
#   Neena/NNP
#   Malcolm/NNP
#   Chaise/NNP
#   JLew/NNP
#   ATL/NNP
#   lt/VBZ
#   333/CD
#   Love/NNP
#   Much/NNP
#   ./.
#   ,/,
#   --/:
#   ./.
#   Triiiiiii/NNP
#   ./.
#   ily/RB
#   ./.
#   even/RB
#   if/IN
#   (NE Chaise/NNP)
#   doesn/NN
#   t/NN
#   ./.
#   D/NNP
#   *dies/NNS
#   of/IN
#   laughter*/NN
#   ,/,
#   ../VBP
#   i/JJ
#   wantt/VBP
#   hiim/JJ
#   soo/NN
#   badd/NN
#   ,/,
#   ../JJ
#   watching/VBG
#   tv/NN
#   bed/VBD
#   shopping/VBG
#   w./NN
#   mom/NN
#   out/IN
#   w./JJ
#   trent/JJ
#   hopefully/RB
#   i/VBP
#   need/VBP
#   my/PRP$
#   best/JJS
#   friend/NN
#   ,/,
#   .../:
#   had/VBD
#   weird/JJ
#   encounters/NNS
#   with/IN
#   so/RB
#   many/JJ
#   homeless/JJ
#   creeps/NNS
#   on/IN
#   the/DT
#   walk/NN
#   home/NN
#   tonight/NN
#   all/DT
#   by/IN
#   myself/PRP
#   awesome/VBP
#   .../:
#   really/RB
#   .../:
#   ,/,
#   .../:
#   Rained/VBN
#   out/RP
#   truck/NN
#   race/NN
#   ,/,
#   .../:
#   Why/WRB
#   am/VBP
#   I/PRP
#   feeling/VBG
#   worse/JJR
#   F/NNP
#   ,/,
#   .../:
#   ./.
#   Feeling/VBG
#   pain/NN
#   and/CC
#   happiness/NN
#   at/IN
#   the/DT
#   same/JJ
#   time/NN
#   ./.
#   How/WRB
#   confusing/JJ
#   ,/,
#   .../:
#   ../PRP
#   hot/JJ
#   choco/NN
#   is/VBZ
#   the/DT
#   best/JJS
#   ,/,
#   .../:
#   .in/VBZ
#   a/DT
#   shirt/NN
#   and/CC
#   panties/NNS
#   ./.
#   celulite/NN
#   ,/,
#   ..had/VBD
#   to/TO
#   turn/VB
#   back/RB
#   to/TO
#   (NE North/NNP)
#   due/JJ
#   to/TO
#   body/VB
#   on/IN
#   line/NN
#   ./.
#   So/IN
#   missing/VBG
#   (NE Design/NNP Council/NNP)
#   Design/NNP
#   4/CD
#   Tech/NNP
#   Transfer/NNP
#   event/NN
#   ,/,
#   ..y/NNP
#   everything/NN
#   is/VBZ
#   so/RB
#   hard/JJ
#   ,/,
#   .bueno/JJ
#   good/JJ
#   bye/NN
#   ./.
#   good/JJ
#   night/NN
#   ,/,
#   (NE Beach/NNP)
#   day/NN
#   with/IN
#   (NE Scoobs/NNP)
#   ./.
#   Still/RB
#   no/DT
#   phone./NN
#   ,/,
#   Let/NNP
#   s/PRP
#   have/VB
#   fun/VBN
#   ./.
#   When/WRB
#   I/PRP
#   give/VBP
#   ya/PRP
#   what/WP
#   I/PRP
#   give/VBP
#   ya./NN
#   ,/,
#   I/PRP
#   don/VBP
#   t/JJ
#   want/VBP
#   to/TO
#   move/VB
#   ,/,
#   -D/NN
#   .../:
#   WHAT/WP
#   AN/NNP
#   AMAZING/JJ
#   (NE NIGHT/NNP)
#   DAY/NNP
#   amp/VBD
#   (NE NIGHT/NNP)
#   AGAIN/NNP
#   HI/NNP
#   TWITS/NNP
#   I/PRP
#   (NE MiSS/NNP)
#   U/NNP
#   GUYS/NNP
#   ,/,
#   canaveral/JJ
#   national/JJ
#   seashore/NN
#   ,/,
#   progressing/VBG
#   in/IN
#   the/DT
#   production/NN
#   department/NN
#   with/IN
#   quot/PDT
#   The/DT
#   Uprizing/NNP
#   quot/NN
#   thats/VBZ
#   the/DT
#   priority/NN
#   getting/VBG
#   the/DT
#   head/NN
#   nodding/VBG
#   beats/NNS
#   and/CC
#   then/RB
#   we/PRP
#   reach/VBP
#   out/RP
#   ,/,
#   taylorrhicks/NNS
#   enjoy/VBP
#   chicago..b/JJ
#   new/JJ
#   venue/NN
#   is/VBZ
#   always/RB
#   cool/JJ
#   ./.
#   You/PRP
#   shine/VBP
#   everywhere/RB
#   you/PRP
#   go/VBP
#   ./.
#   I/PRP
#   know/VBP
#   who/WP
#   you/PRP
#   are/VBP
#   ./.
#   In/IN
#   time/NN
#   so/RB
#   will/MD
#   everyone/NN
#   ./.
#   ,/,
#   the/DT
#   train/NN
#   crash/NN
#   in/IN
#   (NE DC/NNP)
#   .../:
#   ../NN
#   ,/,
#   Thestreetforce/NNP
#   ,/,
#   3sixty5days/CD
#   makes/VBZ
#   me/PRP
#   smile./JJ
#   ,/,
#   adamisacson/JJ
#   My/NNP
#   first/RB
#   day/NN
#   off/IN
#   in/IN
#   3/CD
#   weeks/NNS
#   and/CC
#   my/PRP$
#   child/NN
#   got/VBD
#   up/RB
#   before/RB
#   7/CD
#   00/CD
#   ./.
#   So/RB
#   watch/NN
#   for/IN
#   me/PRP
#   on/IN
#   quot/NN
#   (NE Nancy/NNP)
#   Grac../NNP
#   ,/,
#   adbert/JJ
#   quot/NN
#   (NE Video/NNP Woody/NNP)
#   Woodpecker/NNP
#   The/DT
#   Barber/NNP
#   of/IN
#   Seville/NNP
#   I/PRP
#   am/VBP
#   great/JJ
#   klitoria/NN
#   just/RB
#   wishing/VBG
#   to/TO
#   be/VB
#   a/DT
#   ch/NN
#   .../:
#   ,/,
#   alexrauchman/JJ
#   I/PRP
#   am/VBP
#   happy/JJ
#   you/PRP
#   are/VBP
#   staying/VBG
#   around/RB
#   here/RB
#   ./.
#   (NE Drexel/NNP)
#   is/VBZ
#   a/DT
#   fabulous/JJ
#   university/NN
#   ./.
#   You/PRP
#   should/MD
#   be/VB
#   proud/JJ
#   ./.
#   yeah./NN
#   ,/,
#   alvinkschneider/VB
#   what/WP
#   happened/VBD
#   to/TO
#   angels/NNS
#   and/CC
#   demons/NNS
#   and/CC
#   lions/NNS
#   and/CC
#   tigers/NNS
#   and/CC
#   bears/NNS
#   ,/,
#   (NE AmericanWomannn/NNP Well/NNP)
#   that/IN
#   sure/JJ
#   minimizes/VBZ
#   the/DT
#   impact/NN
#   .../:
#   LOL/NNP
#   ,/,
#   ange_black/NN
#   sween/NN
#   I/PRP
#   call/VBP
#   dibs/NNS
#   on/IN
#   the/DT
#   (NE Voltron/NNP)
#   arm/NN
#   ./.
#   No/CC
#   the/DT
#   leg/NN
#   ./.
#   Wait/NNP
#   ./.
#   Where/WRB
#   are/VBP
#   my/PRP$
#   manners/NNS
#   baileygenine/VBP
#   ../NN
#   ,/,
#   CharlottegC/NNP
#   I/PRP
#   just/RB
#   saw/VBD
#   ur/JJ
#   mum/NN
#   ,/,
#   chloelunn/NN
#   and/CC
#   meganmcdowell/VB
#   (NE GET/NNP)
#   YOUR/NNP
#   FAT/NNP
#   ASSES/NNP
#   ON/NNP
#   HERE/NNP
#   ./.
#   NAI./NNP
#   ,/,
#   -/:
#   codinghorror/NN
#   See/NNP
#   three/CD
#   external/JJ
#   monitors/NNS
#   on/IN
#   one/CD
#   laptop/NN
#   Win7RC/NNP
#   1/CD
#   x/VBD
#   1920x1080/CD
#   2/CD
#   x/NN
#   1280x1024/CD
#   ,/,
#   copicmarker/NN
#   quot/NN
#   facebook.com/NN
#   copic.marker/NN
#   if/IN
#   you/PRP
#   re/VBP
#   cool/JJ
#   ./.
#   Or/CC
#   if/IN
#   you/PRP
#   re/VBP
#   not/RB
#   cool/JJ
#   ./.
#   Maybe/RB
#   I/PRP
#   ll/VBP
#   send/VB
#   some/DT
#   cool/JJ
#   ../NN
#   ,/,
#   crewislife/VBP
#   you/PRP
#   want/VBP
#   to/TO
#   start/VB
#   the/DT
#   morning/NN
#   later/RB
#   in/IN
#   (NE New/NNP York/NNP)
#   we/PRP
#   can/MD
#   do/VB
#   that/DT
#   Californians/NNPS
#   have/VBP
#   it/PRP
#   even/RB
#   better/RBR
#   ,/,
#   cybervenus/JJ
#   (NE LOL/NNP)
#   LuV/NNP
#   IT/NNP
#   gt/VBD
#   gt/NN
#   Did/NNP
#   any1/VB
#   find/NN
#   or/CC
#   c/VB
#   1/CD
#   a../NN
#   ,/,
#   dandelionas/NN
#   is/VBZ
#   making/VBG
#   fettucini/NNS
#   and/CC
#   garlic/JJ
#   bread/NN
#   ,/,
#   danregal/JJ
#   tell/VBP
#   pfont/NN
#   i/NN
#   said/VBD
#   (NE Happy/JJ)
#   BDay/NNP
#   ,/,
#   -/:
#   (NE Darcy_Lussier/NNP)
#   lkrammes/VBZ
#   I/PRP
#   went/VBD
#   to/TO
#   work/VB
#   once/RB
#   last/JJ
#   year/NN
#   with/IN
#   no/DT
#   pants/NNS
#   ./.
#   Ironically/RB
#   that/DT
#   was/VBD
#   my/PRP$
#   last/JJ
#   day/NN
#   of/IN
#   work/NN
#   at/IN
#   that/DT
#   job/NN
#   ./.
#   (NE FML/NNP)
#   ,/,
#   (NE DirtyRose17/NNP)
#   told/VBD
#   you/PRP
#   you/PRP
#   would/MD
#   sweep/VB
#   haha/NN
#   -p/NNP
#   ,/,
#   dreamingspires/VBZ
#   ./.
#   there/EX
#   r/VBZ
#   many/JJ
#   gr8/NNS
#   science/NN
#   cartoons/NNS
#   ,/,
#   -/:
#   (NE Em91/NNP Edinburgh/NNP)
#   fringe/NN
#   is/VBZ
#   only/RB
#   10/CD
#   weeks/NNS
#   away/RB
#   I/PRP
#   need/VBP
#   monies/NNS
#   Btw/NNP
#   I/PRP
#   m/VBP
#   Elliott/RB
#   from/IN
#   angryfeet/NN
#   -/:
#   blame/NN
#   (NE howlieT/NN)
#   for/IN
#   the/DT
#   Twitter/NNP
#   intrusion/NN)
